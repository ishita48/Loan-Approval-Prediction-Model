# %% [markdown]
# <a href="https://colab.research.google.com/github/ishita48/Loan-Approval-Prediction-Model/blob/main/loan_approval_prediction_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SETUP AND DATA LOADING

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
# Load dataset (replace with your dataset path)
df = pd.read_csv('train.csv')

# Display first few rows and check data types
print(df.head())
print(df.info())

#Dataset Shape
df.shape

# Summary statistics
print(df.describe())

# Check for missing values
print(df.isnull().sum())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
# None
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# DATA PREPROCESSING

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].median())
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.shape
# Out:
# (542, 13)

# %% [markdown]
#  Exploratory Data Analysis (EDA)
#
# Univariate Analysis: Analyzing individual columns.
#
# Bivariate Analysis: Analyzing relationships between two variables.
#
# Multivariate Analysis: Analyzing relationships between multiple variables.
#
# Missing Values Analysis: Understanding the pattern of missing values.
#
# Outliers Analysis: Detecting and understanding outlier

# %%
# Univariate Analysis - Distribution of numerical features
fig, ax = plt.subplots(2, 3, figsize=(20, 12))

sns.histplot(df['ApplicantIncome'], bins=20, kde=True, ax=ax[0, 0])
ax[0, 0].set_title('Applicant Income Distribution')

sns.histplot(df['CoapplicantIncome'], bins=20, kde=True, ax=ax[0, 1])
ax[0, 1].set_title('Coapplicant Income Distribution')

sns.histplot(df['LoanAmount'], bins=20, kde=True, ax=ax[0, 2])
ax[0, 2].set_title('Loan Amount Distribution')

sns.histplot(df['Loan_Amount_Term'], bins=20, kde=True, ax=ax[1, 0])
ax[1, 0].set_title('Loan Amount Term Distribution')

sns.countplot(x='Credit_History', data=df, ax=ax[1, 1])
ax[1, 1].set_title('Credit History Distribution')

sns.countplot(x='Dependents', data=df, ax=ax[1, 2])
ax[1, 2].set_title('Dependents Distribution')

plt.tight_layout()
plt.show()

# Univariate Analysis - Distribution of categorical features
fig, ax = plt.subplots(2, 3, figsize=(20, 12))

sns.countplot(x='Gender', data=df, ax=ax[0, 0])
ax[0, 0].set_title('Gender Distribution')

sns.countplot(x='Married', data=df, ax=ax[0, 1])
ax[0, 1].set_title('Married Distribution')

sns.countplot(x='Education', data=df, ax=ax[0, 2])
ax[0, 2].set_title('Education Distribution')

sns.countplot(x='Self_Employed', data=df, ax=ax[1, 0])
ax[1, 0].set_title('Self Employed Distribution')

sns.countplot(x='Property_Area', data=df, ax=ax[1, 1])
ax[1, 1].set_title('Property Area Distribution')

sns.countplot(x='Loan_Status', data=df, ax=ax[1, 2])
ax[1, 2].set_title('Loan Status Distribution')

plt.tight_layout()
plt.show()

# %%
# Bivariate Analysis - Categorical vs Target Variable
fig, ax = plt.subplots(2, 3, figsize=(20, 12))

sns.countplot(x='Gender', hue='Loan_Status', data=df, ax=ax[0, 0])
ax[0, 0].set_title('Gender vs Loan Status')

sns.countplot(x='Married', hue='Loan_Status', data=df, ax=ax[0, 1])
ax[0, 1].set_title('Married vs Loan Status')

sns.countplot(x='Education', hue='Loan_Status', data=df, ax=ax[0, 2])
ax[0, 2].set_title('Education vs Loan Status')

sns.countplot(x='Self_Employed', hue='Loan_Status', data=df, ax=ax[1, 0])
ax[1, 0].set_title('Self Employed vs Loan Status')

sns.countplot(x='Property_Area', hue='Loan_Status', data=df, ax=ax[1, 1])
ax[1, 1].set_title('Property Area vs Loan Status')

sns.countplot(x='Credit_History', hue='Loan_Status', data=df, ax=ax[1, 2])
ax[1, 2].set_title('Credit History vs Loan Status')

plt.tight_layout()
plt.show()

# Bivariate Analysis - Numerical vs Target Variable
fig, ax = plt.subplots(2, 2, figsize=(20, 12))

sns.boxplot(x='Loan_Status', y='ApplicantIncome', data=df, ax=ax[0, 0])
ax[0, 0].set_title('Applicant Income vs Loan Status')

sns.boxplot(x='Loan_Status', y='CoapplicantIncome', data=df, ax=ax[0, 1])
ax[0, 1].set_title('Coapplicant Income vs Loan Status')

sns.boxplot(x='Loan_Status', y='LoanAmount', data=df, ax=ax[1, 0])
ax[1, 0].set_title('Loan Amount vs Loan Status')

sns.boxplot(x='Loan_Status', y='Loan_Amount_Term', data=df, ax=ax[1, 1])
ax[1, 1].set_title('Loan Amount Term vs Loan Status')

plt.tight_layout()
plt.show()

# %%
# Exclude non-numeric columns for correlation matrix
numeric_df = df.select_dtypes(include=[np.number])

# Multivariate Analysis - Correlation Heatmap
plt.figure(figsize=(12, 8))
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Missing Values Analysis
plt.figure(figsize=(12, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Values')
plt.show()

# Missing values count
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %%
# Outliers Analysis - Boxplots
fig, ax = plt.subplots(2, 2, figsize=(20, 12))

sns.boxplot(df['ApplicantIncome'], ax=ax[0, 0])
ax[0, 0].set_title('Applicant Income Boxplot')

sns.boxplot(df['CoapplicantIncome'], ax=ax[0, 1])
ax[0, 1].set_title('Coapplicant Income Boxplot')

sns.boxplot(df['LoanAmount'], ax=ax[1, 0])
ax[1, 0].set_title('Loan Amount Boxplot')

sns.boxplot(df['Loan_Amount_Term'], ax=ax[1, 1])
ax[1, 1].set_title('Loan Amount Term Boxplot')

plt.tight_layout()
plt.show()

# %%
# Visualizations
sns.countplot(x='Loan_Status', data=df)
plt.title('Loan Approval Status')
plt.show()

sns.boxplot(x='Loan_Status', y='ApplicantIncome', data=df)
plt.title('Applicant Income by Loan Approval Status')
plt.show()

# %%
df['Loan_Status'].replace('Y',1,inplace=True)
df['Loan_Status'].replace('N',0,inplace=True)
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# 1    376
# 0    166
# Name: count, dtype: int64

# %%
df.Gender=df.Gender.map({'Male':1,'Female':0})
df['Gender'].value_counts()
df.Married=df.Married.map({'Yes':1,'No':0})
df['Married'].value_counts()
df.Dependents=df.Dependents.map({'0':0,'1':1,'2':2,'3+':3})
df['Dependents'].value_counts()
df.Education=df.Education.map({'Graduate':1,'Not Graduate':0})
df['Education'].value_counts()
df.Self_Employed=df.Self_Employed.map({'Yes':1,'No':0})
df['Self_Employed'].value_counts()
df.Property_Area=df.Property_Area.map({'Urban':2,'Rural':0,'Semiurban':1})
df['Property_Area'].value_counts()
df['LoanAmount'].value_counts()
df['Loan_Amount_Term'].value_counts()
df['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    468
# 0.0     74
# Name: count, dtype: int64

# %% [markdown]
# From the above figure, we can see that Credit_History (Independent Variable) has the maximum correlation with Loan_Status (Dependent Variable). Which denotes that the Loan_Status is heavily dependent on the Credit_History.

# %%
# Fill missing values
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df['Married'].fillna(df['Married'].mode()[0], inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0], inplace=True)
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)

# Encode categorical variables
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df['Married'] = le.fit_transform(df['Married'])
df['Education'] = le.fit_transform(df['Education'])
df['Self_Employed'] = le.fit_transform(df['Self_Employed'])
df['Property_Area'] = le.fit_transform(df['Property_Area'])
df['Loan_Status'] = le.fit_transform(df['Loan_Status'])
df['Dependents'] = df['Dependents'].replace('3+', 3).astype(int)

# %% [markdown]
# #FINAL DATAFRAME

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          1              0
# 1  LP001003       1        1           1          1              0
# 2  LP001005       1        1           0          1              1
# 3  LP001006       1        1           0          0              0
# 4  LP001008       1        0           0          1              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# 2             1.0              2            1
# 3             1.0              2            1
# 4             1.0              2            1

# %%
# Feature Scaling
scaler = StandardScaler()
df[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']] = scaler.fit_transform(df[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])

# Splitting the dataset into training and testing sets
X = df.drop(columns=['Loan_ID', 'Loan_Status'])
y = df['Loan_Status']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Model Building and Evaluation

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'SVM': SVC(probability=True),
    'Neural Network (Small)': MLPClassifier(hidden_layer_sizes=(100), max_iter=2000, verbose=True),
    'Neural Network (Medium)': MLPClassifier(hidden_layer_sizes=(100), max_iter=2000, verbose=True),
    'Neural Network (Large)': MLPClassifier(hidden_layer_sizes=(100,), max_iter=2000, verbose=True)
}

# %% [markdown]
# Function to evaluate models

# %%
def evaluate_model(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    cm = confusion_matrix(y_test, y_test_pred)
    report = classification_report(y_test, y_test_pred)

    return train_accuracy, test_accuracy, cm, report, model

# %% [markdown]
# Evaluating all models

# %%
results = {}
history = {}

for model_name, model in models.items():
    print(f"Training {model_name}...")
    train_accuracy, test_accuracy, cm, report, trained_model = evaluate_model(model, X_train, X_test, y_train, y_test)
    results[model_name] = {
        'train_accuracy': train_accuracy,
        'test_accuracy': test_accuracy,
        'confusion_matrix': cm,
        'classification_report': report
    }
    if "Neural Network" in model_name:
        history[model_name] = trained_model.loss_curve_
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration 840, loss = 0.21816217
# Iteration 841, loss = 0.21885499
# Iteration 842, loss = 0.21783033
# Iteration 843, loss = 0.21779699
# Iteration 844, loss = 0.21770584
# Iteration 845, loss = 0.21746276
# Iteration 846, loss = 0.21732190
# Iteration 847, loss = 0.21733054
# Iteration 848, loss = 0.21705535
# Iteration 849, loss = 0.21686484
# Iteration 850, loss = 0.21669627
# Iteration 851, loss = 0.21659889
# Iteration 852, loss = 0.21651204
# Iteration 853, loss = 0.21635109
# Iteration 854, loss = 0.21639081
# Iteration 855, loss = 0.21641577
# Iteration 856, loss = 0.21594748
# Iteration 857, loss = 0.21572078
# Iteration 858, loss = 0.21554312
# Iteration 859, loss = 0.21534426
# Iteration 860, loss = 0.21529588
# Iteration 861, loss = 0.21503823
# Iteration 862, loss = 0.21508502
# Iteration 863, loss = 0.21484496
# Iteration 864, loss = 0.21495354
# Iteration 865, loss = 0.21449980
# Iteration 866, loss = 0.21440236
# Iteration 867, loss = 0.21420408
# Iteration 868, loss = 0.21407683
# Iteration 869, loss = 0.21385868
# Iteration 870, loss = 0.21375333
# Iteration 871, loss = 0.21364016
# Iteration 872, loss = 0.21341878
# Iteration 873, loss = 0.21323417
# Iteration 874, loss = 0.21350773
# Iteration 875, loss = 0.21293537
# Iteration 876, loss = 0.21274148
# Iteration 877, loss = 0.21285921
# Iteration 878, loss = 0.21261694
# Iteration 879, loss = 0.21242814
# Iteration 880, loss = 0.21230095
# Iteration 881, loss = 0.21219358
# Iteration 882, loss = 0.21209509
# Iteration 883, loss = 0.21195522
# Iteration 884, loss = 0.21165839
# Iteration 885, loss = 0.21175606
# Iteration 886, loss = 0.21154430
# Iteration 887, loss = 0.21137739
# Iteration 888, loss = 0.21127100
# Iteration 889, loss = 0.21128192
# Iteration 890, loss = 0.21092493
# Iteration 891, loss = 0.21109663
# Iteration 892, loss = 0.21083615
# Iteration 893, loss = 0.21035312
# Iteration 894, loss = 0.21024145
# Iteration 895, loss = 0.21013405
# Iteration 896, loss = 0.20997036
# Iteration 897, loss = 0.20990189
# Iteration 898, loss = 0.20992337
# Iteration 899, loss = 0.20965131
# Iteration 900, loss = 0.20942673
# Iteration 901, loss = 0.20926453
# Iteration 902, loss = 0.20909608
# Iteration 903, loss = 0.20949024
# Iteration 904, loss = 0.20900642
# Iteration 905, loss = 0.20887929
# Iteration 906, loss = 0.20863065
# Iteration 907, loss = 0.20860067
# Iteration 908, loss = 0.20839787
# Iteration 909, loss = 0.20813337
# Iteration 910, loss = 0.20816126
# Iteration 911, loss = 0.20842638
# Iteration 912, loss = 0.20788780
# Iteration 913, loss = 0.20750004
# Iteration 914, loss = 0.20755872
# Iteration 915, loss = 0.20768069
# Iteration 916, loss = 0.20731828
# Iteration 917, loss = 0.20756446
# Iteration 918, loss = 0.20697985
# Iteration 919, loss = 0.20710010
# Iteration 920, loss = 0.20682584
# Iteration 921, loss = 0.20661294
# Iteration 922, loss = 0.20647477
# Iteration 923, loss = 0.20624549
# Iteration 924, loss = 0.20602426
# Iteration 925, loss = 0.20612614
# Iteration 926, loss = 0.20588258
# Iteration 927, loss = 0.20572748
# Iteration 928, loss = 0.20566239
# Iteration 929, loss = 0.20533533
# Iteration 930, loss = 0.20536926
# Iteration 931, loss = 0.20517969
# Iteration 932, loss = 0.20498614
# Iteration 933, loss = 0.20484978
# Iteration 934, loss = 0.20478383
# Iteration 935, loss = 0.20478776
# Iteration 936, loss = 0.20467136
# Iteration 937, loss = 0.20432459
# Iteration 938, loss = 0.20408329
# Iteration 939, loss = 0.20396669
# Iteration 940, loss = 0.20376966
# Iteration 941, loss = 0.20454973
# Iteration 942, loss = 0.20352524
# Iteration 943, loss = 0.20368120
# Iteration 944, loss = 0.20339436
# Iteration 945, loss = 0.20324234
# Iteration 946, loss = 0.20306521
# Iteration 947, loss = 0.20285029
# Iteration 948, loss = 0.20283134
# Iteration 949, loss = 0.20278816
# Iteration 950, loss = 0.20261841
# Iteration 951, loss = 0.20232577
# Iteration 952, loss = 0.20217315
# Iteration 953, loss = 0.20221215
# Iteration 954, loss = 0.20190713
# Iteration 955, loss = 0.20178055
# Iteration 956, loss = 0.20185318
# Iteration 957, loss = 0.20147756
# Iteration 958, loss = 0.20137570
# Iteration 959, loss = 0.20133617
# Iteration 960, loss = 0.20113664
# Iteration 961, loss = 0.20097276
# Iteration 962, loss = 0.20087815
# Iteration 963, loss = 0.20068667
# Iteration 964, loss = 0.20055076
# Iteration 965, loss = 0.20050337
# Iteration 966, loss = 0.20028229
# Iteration 967, loss = 0.20012261
# Iteration 968, loss = 0.20006550
# Iteration 969, loss = 0.20005538
# Iteration 970, loss = 0.19978269
# Iteration 971, loss = 0.19977495
# Iteration 972, loss = 0.19997842
# Iteration 973, loss = 0.19934440
# Iteration 974, loss = 0.19924143
# Iteration 975, loss = 0.19909777
# Iteration 976, loss = 0.19937599
# Iteration 977, loss = 0.19894265
# Iteration 978, loss = 0.19863551
# Iteration 979, loss = 0.19850449
# Iteration 980, loss = 0.19840532
# Iteration 981, loss = 0.19837784
# Iteration 982, loss = 0.19844378
# Iteration 983, loss = 0.19809543
# Iteration 984, loss = 0.19831277
# Iteration 985, loss = 0.19831518
# Iteration 986, loss = 0.19782010
# Iteration 987, loss = 0.19784243
# Iteration 988, loss = 0.19745698
# Iteration 989, loss = 0.19726744
# Iteration 990, loss = 0.19712428
# Iteration 991, loss = 0.19699530
# Iteration 992, loss = 0.19688217
# Iteration 993, loss = 0.19680736
# Iteration 994, loss = 0.19651655
# Iteration 995, loss = 0.19653034
# Iteration 996, loss = 0.19635167
# Iteration 997, loss = 0.19622688
# Iteration 998, loss = 0.19610774
# Iteration 999, loss = 0.19623545
# Iteration 1000, loss = 0.19598366
# Iteration 1001, loss = 0.19561869
# Iteration 1002, loss = 0.19566009
# Iteration 1003, loss = 0.19550481
# Iteration 1004, loss = 0.19532784
# Iteration 1005, loss = 0.19514220
# Iteration 1006, loss = 0.19542881
# Iteration 1007, loss = 0.19523491
# Iteration 1008, loss = 0.19494128
# Iteration 1009, loss = 0.19542033
# Iteration 1010, loss = 0.19471063
# Iteration 1011, loss = 0.19472646
# Iteration 1012, loss = 0.19447104
# Iteration 1013, loss = 0.19440265
# Iteration 1014, loss = 0.19434228
# Iteration 1015, loss = 0.19418503
# Iteration 1016, loss = 0.19388077
# Iteration 1017, loss = 0.19376227
# Iteration 1018, loss = 0.19382297
# Iteration 1019, loss = 0.19384468
# Iteration 1020, loss = 0.19330038
# Iteration 1021, loss = 0.19311043
# Iteration 1022, loss = 0.19318727
# Iteration 1023, loss = 0.19298362
# Iteration 1024, loss = 0.19270002
# Iteration 1025, loss = 0.19254814
# Iteration 1026, loss = 0.19244712
# Iteration 1027, loss = 0.19250770
# Iteration 1028, loss = 0.19236107
# Iteration 1029, loss = 0.19209232
# Iteration 1030, loss = 0.19201662
# Iteration 1031, loss = 0.19194193
# Iteration 1032, loss = 0.19172588
# Iteration 1033, loss = 0.19169300
# Iteration 1034, loss = 0.19249700
# Iteration 1035, loss = 0.19221953
# Iteration 1036, loss = 0.19129104
# Iteration 1037, loss = 0.19117743
# Iteration 1038, loss = 0.19098262
# Iteration 1039, loss = 0.19092206
# Iteration 1040, loss = 0.19093766
# Iteration 1041, loss = 0.19065927
# Iteration 1042, loss = 0.19055501
# Iteration 1043, loss = 0.19053700
# Iteration 1044, loss = 0.19034249
# Iteration 1045, loss = 0.19057443
# Iteration 1046, loss = 0.19027374
# Iteration 1047, loss = 0.18988275
# Iteration 1048, loss = 0.18974818
# Iteration 1049, loss = 0.18997766
# Iteration 1050, loss = 0.18950150
# Iteration 1051, loss = 0.18936383
# Iteration 1052, loss = 0.18931020
# Iteration 1053, loss = 0.18924828
# Iteration 1054, loss = 0.18904370
# Iteration 1055, loss = 0.18892309
# Iteration 1056, loss = 0.18912673
# Iteration 1057, loss = 0.18866346
# Iteration 1058, loss = 0.18860360
# Iteration 1059, loss = 0.18862423
# Iteration 1060, loss = 0.18833636
# Iteration 1061, loss = 0.18822576
# Iteration 1062, loss = 0.18802593
# Iteration 1063, loss = 0.18810834
# Iteration 1064, loss = 0.18858305
# Iteration 1065, loss = 0.18772652
# Iteration 1066, loss = 0.18765376
# Iteration 1067, loss = 0.18764551
# Iteration 1068, loss = 0.18750002
# Iteration 1069, loss = 0.18711903
# Iteration 1070, loss = 0.18703699
# Iteration 1071, loss = 0.18701512
# Iteration 1072, loss = 0.18690559
# Iteration 1073, loss = 0.18669755
# Iteration 1074, loss = 0.18662743
# Iteration 1075, loss = 0.18664230
# Iteration 1076, loss = 0.18642187
# Iteration 1077, loss = 0.18613817
# Iteration 1078, loss = 0.18611010
# Iteration 1079, loss = 0.18595721
# Iteration 1080, loss = 0.18579729
# Iteration 1081, loss = 0.18570992
# Iteration 1082, loss = 0.18563512
# Iteration 1083, loss = 0.18550871
# Iteration 1084, loss = 0.18540745
# Iteration 1085, loss = 0.18551615
# Iteration 1086, loss = 0.18521495
# Iteration 1087, loss = 0.18500550
# Iteration 1088, loss = 0.18494249
# Iteration 1089, loss = 0.18478014
# Iteration 1090, loss = 0.18461151
# Iteration 1091, loss = 0.18450585
# Iteration 1092, loss = 0.18442707
# Iteration 1093, loss = 0.18437567
# Iteration 1094, loss = 0.18415158
# Iteration 1095, loss = 0.18405001
# Iteration 1096, loss = 0.18401911
# Iteration 1097, loss = 0.18375466
# Iteration 1098, loss = 0.18392974
# Iteration 1099, loss = 0.18373432
# Iteration 1100, loss = 0.18341051
# Iteration 1101, loss = 0.18325595
# Iteration 1102, loss = 0.18339293
# Iteration 1103, loss = 0.18351172
# Iteration 1104, loss = 0.18315368
# Iteration 1105, loss = 0.18292447
# Iteration 1106, loss = 0.18284532
# Iteration 1107, loss = 0.18275302
# Iteration 1108, loss = 0.18250323
# Iteration 1109, loss = 0.18235749
# Iteration 1110, loss = 0.18226397
# Iteration 1111, loss = 0.18210039
# Iteration 1112, loss = 0.18206658
# Iteration 1113, loss = 0.18194308
# Iteration 1114, loss = 0.18194470
# Iteration 1115, loss = 0.18172701
# Iteration 1116, loss = 0.18155087
# Iteration 1117, loss = 0.18132561
# Iteration 1118, loss = 0.18129467
# Iteration 1119, loss = 0.18124143
# Iteration 1120, loss = 0.18136895
# Iteration 1121, loss = 0.18085800
# Iteration 1122, loss = 0.18068622
# Iteration 1123, loss = 0.18064948
# Iteration 1124, loss = 0.18182503
# Iteration 1125, loss = 0.18052850
# Iteration 1126, loss = 0.18039452
# Iteration 1127, loss = 0.18026558
# Iteration 1128, loss = 0.18006024
# Iteration 1129, loss = 0.17993765
# Iteration 1130, loss = 0.17992025
# Iteration 1131, loss = 0.17972448
# Iteration 1132, loss = 0.17964822
# Iteration 1133, loss = 0.17964552
# Iteration 1134, loss = 0.17931458
# Iteration 1135, loss = 0.17923541
# Iteration 1136, loss = 0.17927591
# Iteration 1137, loss = 0.17905811
# Iteration 1138, loss = 0.17879013
# Iteration 1139, loss = 0.17880151
# Iteration 1140, loss = 0.17896171
# Iteration 1141, loss = 0.17879004
# Iteration 1142, loss = 0.17885475
# Iteration 1143, loss = 0.17854882
# Iteration 1144, loss = 0.17822942
# Iteration 1145, loss = 0.17807177
# Iteration 1146, loss = 0.17792008
# Iteration 1147, loss = 0.17778281
# Iteration 1148, loss = 0.17768876
# Iteration 1149, loss = 0.17761309
# Iteration 1150, loss = 0.17744866
# Iteration 1151, loss = 0.17751492
# Iteration 1152, loss = 0.17716594
# Iteration 1153, loss = 0.17741668
# Iteration 1154, loss = 0.17726296
# Iteration 1155, loss = 0.17682283
# Iteration 1156, loss = 0.17694150
# Iteration 1157, loss = 0.17708199
# Iteration 1158, loss = 0.17651452
# Iteration 1159, loss = 0.17634298
# Iteration 1160, loss = 0.17638169
# Iteration 1161, loss = 0.17604608
# Iteration 1162, loss = 0.17611561
# Iteration 1163, loss = 0.17567928
# Iteration 1164, loss = 0.17559497
# Iteration 1165, loss = 0.17568624
# Iteration 1166, loss = 0.17563415
# Iteration 1167, loss = 0.17532432
# Iteration 1168, loss = 0.17506585
# Iteration 1169, loss = 0.17489577
# Iteration 1170, loss = 0.17485557
# Iteration 1171, loss = 0.17496676
# Iteration 1172, loss = 0.17455518
# Iteration 1173, loss = 0.17439314
# Iteration 1174, loss = 0.17478194
# Iteration 1175, loss = 0.17436403
# Iteration 1176, loss = 0.17411710
# Iteration 1177, loss = 0.17392793
# Iteration 1178, loss = 0.17385004
# Iteration 1179, loss = 0.17386723
# Iteration 1180, loss = 0.17353435
# Iteration 1181, loss = 0.17350497
# Iteration 1182, loss = 0.17349845
# Iteration 1183, loss = 0.17325359
# Iteration 1184, loss = 0.17304155
# Iteration 1185, loss = 0.17351177
# Iteration 1186, loss = 0.17303962
# Iteration 1187, loss = 0.17294320
# Iteration 1188, loss = 0.17260991
# Iteration 1189, loss = 0.17279256
# Iteration 1190, loss = 0.17251567
# Iteration 1191, loss = 0.17264551
# Iteration 1192, loss = 0.17226001
# Iteration 1193, loss = 0.17238188
# Iteration 1194, loss = 0.17207730
# Iteration 1195, loss = 0.17196275
# Iteration 1196, loss = 0.17198122
# Iteration 1197, loss = 0.17165515
# Iteration 1198, loss = 0.17204029
# Iteration 1199, loss = 0.17145060
# Iteration 1200, loss = 0.17123067
# Iteration 1201, loss = 0.17137027
# Iteration 1202, loss = 0.17101137
# Iteration 1203, loss = 0.17103805
# Iteration 1204, loss = 0.17078497
# Iteration 1205, loss = 0.17070493
# Iteration 1206, loss = 0.17136901
# Iteration 1207, loss = 0.17064906
# Iteration 1208, loss = 0.17063554
# Iteration 1209, loss = 0.17056461
# Iteration 1210, loss = 0.17046936
# Iteration 1211, loss = 0.17064783
# Iteration 1212, loss = 0.17005421
# Iteration 1213, loss = 0.16980650
# Iteration 1214, loss = 0.16977231
# Iteration 1215, loss = 0.16960470
# Iteration 1216, loss = 0.16950334
# Iteration 1217, loss = 0.16936349
# Iteration 1218, loss = 0.16929142
# Iteration 1219, loss = 0.16913384
# Iteration 1220, loss = 0.16923447
# Iteration 1221, loss = 0.16905563
# Iteration 1222, loss = 0.16891621
# Iteration 1223, loss = 0.16869885
# Iteration 1224, loss = 0.16886625
# Iteration 1225, loss = 0.16865404
# Iteration 1226, loss = 0.16842061
# Iteration 1227, loss = 0.16826641
# Iteration 1228, loss = 0.16825265
# Iteration 1229, loss = 0.16863801
# Iteration 1230, loss = 0.16809358
# Iteration 1231, loss = 0.16793764
# Iteration 1232, loss = 0.16791317
# Iteration 1233, loss = 0.16810733
# Iteration 1234, loss = 0.16769081
# Iteration 1235, loss = 0.16752066
# Iteration 1236, loss = 0.16738741
# Iteration 1237, loss = 0.16733227
# Iteration 1238, loss = 0.16741033
# Iteration 1239, loss = 0.16707583
# Iteration 1240, loss = 0.16697554
# Iteration 1241, loss = 0.16677968
# Iteration 1242, loss = 0.16667671
# Iteration 1243, loss = 0.16670685
# Iteration 1244, loss = 0.16667031
# Iteration 1245, loss = 0.16685602
# Iteration 1246, loss = 0.16642305
# Iteration 1247, loss = 0.16643212
# Iteration 1248, loss = 0.16645546
# Iteration 1249, loss = 0.16624158
# Iteration 1250, loss = 0.16606486
# Iteration 1251, loss = 0.16634365
# Iteration 1252, loss = 0.16576801
# Iteration 1253, loss = 0.16564720
# Iteration 1254, loss = 0.16561740
# Iteration 1255, loss = 0.16542687
# Iteration 1256, loss = 0.16572230
# Iteration 1257, loss = 0.16530089
# Iteration 1258, loss = 0.16520381
# Iteration 1259, loss = 0.16561206
# Iteration 1260, loss = 0.16517243
# Iteration 1261, loss = 0.16486250
# Iteration 1262, loss = 0.16480229
# Iteration 1263, loss = 0.16475795
# Iteration 1264, loss = 0.16491784
# Iteration 1265, loss = 0.16444320
# Iteration 1266, loss = 0.16438952
# Iteration 1267, loss = 0.16432664
# Iteration 1268, loss = 0.16416994
# Iteration 1269, loss = 0.16405061
# Iteration 1270, loss = 0.16394096
# Iteration 1271, loss = 0.16398936
# Iteration 1272, loss = 0.16381645
# Iteration 1273, loss = 0.16357940
# Iteration 1274, loss = 0.16388359
# Iteration 1275, loss = 0.16339473
# Iteration 1276, loss = 0.16334853
# Iteration 1277, loss = 0.16331211
# Iteration 1278, loss = 0.16309829
# Iteration 1279, loss = 0.16302636
# Iteration 1280, loss = 0.16306582
# Iteration 1281, loss = 0.16282363
# Iteration 1282, loss = 0.16279918
# Iteration 1283, loss = 0.16274737
# Iteration 1284, loss = 0.16254015
# Iteration 1285, loss = 0.16269377
# Iteration 1286, loss = 0.16272885
# Iteration 1287, loss = 0.16234569
# Iteration 1288, loss = 0.16237077
# Iteration 1289, loss = 0.16222229
# Iteration 1290, loss = 0.16213853
# Iteration 1291, loss = 0.16186979
# Iteration 1292, loss = 0.16208996
# Iteration 1293, loss = 0.16187532
# Iteration 1294, loss = 0.16156625
# Iteration 1295, loss = 0.16155691
# Iteration 1296, loss = 0.16149323
# Iteration 1297, loss = 0.16124131
# Iteration 1298, loss = 0.16127662
# Iteration 1299, loss = 0.16115841
# Iteration 1300, loss = 0.16124129
# Iteration 1301, loss = 0.16091883
# Iteration 1302, loss = 0.16068799
# Iteration 1303, loss = 0.16066800
# Iteration 1304, loss = 0.16061132
# Iteration 1305, loss = 0.16045550
# Iteration 1306, loss = 0.16028830
# Iteration 1307, loss = 0.16038793
# Iteration 1308, loss = 0.16006020
# Iteration 1309, loss = 0.15999366
# Iteration 1310, loss = 0.15982956
# Iteration 1311, loss = 0.15968632
# Iteration 1312, loss = 0.15974813
# Iteration 1313, loss = 0.15982107
# Iteration 1314, loss = 0.15946662
# Iteration 1315, loss = 0.15938704
# Iteration 1316, loss = 0.15926392
# Iteration 1317, loss = 0.15925287
# Iteration 1318, loss = 0.15901294
# Iteration 1319, loss = 0.15888291
# Iteration 1320, loss = 0.15873640
# Iteration 1321, loss = 0.15904945
# Iteration 1322, loss = 0.15870714
# Iteration 1323, loss = 0.15844817
# Iteration 1324, loss = 0.15842678
# Iteration 1325, loss = 0.15831709
# Iteration 1326, loss = 0.15836257
# Iteration 1327, loss = 0.15826785
# Iteration 1328, loss = 0.15803169
# Iteration 1329, loss = 0.15801519
# Iteration 1330, loss = 0.15795261
# Iteration 1331, loss = 0.15764125
# Iteration 1332, loss = 0.15761518
# Iteration 1333, loss = 0.15744621
# Iteration 1334, loss = 0.15748682
# Iteration 1335, loss = 0.15726996
# Iteration 1336, loss = 0.15718403
# Iteration 1337, loss = 0.15711841
# Iteration 1338, loss = 0.15708382
# Iteration 1339, loss = 0.15683753
# Iteration 1340, loss = 0.15697075
# Iteration 1341, loss = 0.15672786
# Iteration 1342, loss = 0.15674620
# Iteration 1343, loss = 0.15652663
# Iteration 1344, loss = 0.15651146
# Iteration 1345, loss = 0.15628160
# Iteration 1346, loss = 0.15617757
# Iteration 1347, loss = 0.15613598
# Iteration 1348, loss = 0.15607062
# Iteration 1349, loss = 0.15623095
# Iteration 1350, loss = 0.15580786
# Iteration 1351, loss = 0.15599135
# Iteration 1352, loss = 0.15563129
# Iteration 1353, loss = 0.15576233
# Iteration 1354, loss = 0.15536802
# Iteration 1355, loss = 0.15534072
# Iteration 1356, loss = 0.15531185
# Iteration 1357, loss = 0.15538696
# Iteration 1358, loss = 0.15499089
# Iteration 1359, loss = 0.15494407
# Iteration 1360, loss = 0.15495550
# Iteration 1361, loss = 0.15469614
# Iteration 1362, loss = 0.15464238
# Iteration 1363, loss = 0.15456929
# Iteration 1364, loss = 0.15447540
# Iteration 1365, loss = 0.15437495
# Iteration 1366, loss = 0.15445114
# Iteration 1367, loss = 0.15411716
# Iteration 1368, loss = 0.15402552
# Iteration 1369, loss = 0.15392669
# Iteration 1370, loss = 0.15434982
# Iteration 1371, loss = 0.15385704
# Iteration 1372, loss = 0.15361893
# Iteration 1373, loss = 0.15359894
# Iteration 1374, loss = 0.15396764
# Iteration 1375, loss = 0.15421856
# Iteration 1376, loss = 0.15339623
# Iteration 1377, loss = 0.15323579
# Iteration 1378, loss = 0.15306377
# Iteration 1379, loss = 0.15307976
# Iteration 1380, loss = 0.15287172
# Iteration 1381, loss = 0.15280609
# Iteration 1382, loss = 0.15302446
# Iteration 1383, loss = 0.15267154
# Iteration 1384, loss = 0.15244462
# Iteration 1385, loss = 0.15313777
# Iteration 1386, loss = 0.15239891
# Iteration 1387, loss = 0.15219770
# Iteration 1388, loss = 0.15213080
# Iteration 1389, loss = 0.15225910
# Iteration 1390, loss = 0.15209155
# Iteration 1391, loss = 0.15189735
# Iteration 1392, loss = 0.15172837
# Iteration 1393, loss = 0.15226415
# Iteration 1394, loss = 0.15156282
# Iteration 1395, loss = 0.15131003
# Iteration 1396, loss = 0.15131231
# Iteration 1397, loss = 0.15145260
# Iteration 1398, loss = 0.15130654
# Iteration 1399, loss = 0.15115433
# Iteration 1400, loss = 0.15128134
# Iteration 1401, loss = 0.15102267
# Iteration 1402, loss = 0.15070203
# Iteration 1403, loss = 0.15066891
# Iteration 1404, loss = 0.15056704
# Iteration 1405, loss = 0.15043243
# Iteration 1406, loss = 0.15027430
# Iteration 1407, loss = 0.15019932
# Iteration 1408, loss = 0.15019635
# Iteration 1409, loss = 0.15007329
# Iteration 1410, loss = 0.15003845
# Iteration 1411, loss = 0.14996927
# Iteration 1412, loss = 0.14980470
# Iteration 1413, loss = 0.15004915
# Iteration 1414, loss = 0.14959212
# Iteration 1415, loss = 0.14938275
# Iteration 1416, loss = 0.14930175
# Iteration 1417, loss = 0.14950042
# Iteration 1418, loss = 0.14907171
# Iteration 1419, loss = 0.14906563
# Iteration 1420, loss = 0.14943087
# Iteration 1421, loss = 0.14925755
# Iteration 1422, loss = 0.14872464
# Iteration 1423, loss = 0.14864941
# Iteration 1424, loss = 0.14849771
# Iteration 1425, loss = 0.14850316
# Iteration 1426, loss = 0.14831970
# Iteration 1427, loss = 0.14822281
# Iteration 1428, loss = 0.14841438
# Iteration 1429, loss = 0.14798651
# Iteration 1430, loss = 0.14800645
# Iteration 1431, loss = 0.14784509
# Iteration 1432, loss = 0.14766462
# Iteration 1433, loss = 0.14757200
# Iteration 1434, loss = 0.14751892
# Iteration 1435, loss = 0.14755710
# Iteration 1436, loss = 0.14739583
# Iteration 1437, loss = 0.14728899
# Iteration 1438, loss = 0.14707561
# Iteration 1439, loss = 0.14707185
# Iteration 1440, loss = 0.14704664
# Iteration 1441, loss = 0.14673181
# Iteration 1442, loss = 0.14668207
# Iteration 1443, loss = 0.14654315
# Iteration 1444, loss = 0.14673113
# Iteration 1445, loss = 0.14645960
# Iteration 1446, loss = 0.14644056
# Iteration 1447, loss = 0.14624781
# Iteration 1448, loss = 0.14617876
# Iteration 1449, loss = 0.14640659
# Iteration 1450, loss = 0.14590499
# Iteration 1451, loss = 0.14588072
# Iteration 1452, loss = 0.14577844
# Iteration 1453, loss = 0.14560608
# Iteration 1454, loss = 0.14606933
# Iteration 1455, loss = 0.14533843
# Iteration 1456, loss = 0.14545179
# Iteration 1457, loss = 0.14529058
# Iteration 1458, loss = 0.14530852
# Iteration 1459, loss = 0.14517880
# Iteration 1460, loss = 0.14485899
# Iteration 1461, loss = 0.14492987
# Iteration 1462, loss = 0.14496581
# Iteration 1463, loss = 0.14458706
# Iteration 1464, loss = 0.14476672
# Iteration 1465, loss = 0.14454904
# Iteration 1466, loss = 0.14497545
# Iteration 1467, loss = 0.14450550
# Iteration 1468, loss = 0.14411862
# Iteration 1469, loss = 0.14410293
# Iteration 1470, loss = 0.14446243
# Iteration 1471, loss = 0.14387163
# Iteration 1472, loss = 0.14455641
# Iteration 1473, loss = 0.14383657
# Iteration 1474, loss = 0.14363332
# Iteration 1475, loss = 0.14349437
# Iteration 1476, loss = 0.14360464
# Iteration 1477, loss = 0.14343605
# Iteration 1478, loss = 0.14324237
# Iteration 1479, loss = 0.14318512
# Iteration 1480, loss = 0.14301177
# Iteration 1481, loss = 0.14296049
# Iteration 1482, loss = 0.14283124
# Iteration 1483, loss = 0.14278233
# Iteration 1484, loss = 0.14260407
# Iteration 1485, loss = 0.14250074
# Iteration 1486, loss = 0.14252797
# Iteration 1487, loss = 0.14227646
# Iteration 1488, loss = 0.14226043
# Iteration 1489, loss = 0.14239351
# Iteration 1490, loss = 0.14210127
# Iteration 1491, loss = 0.14191214
# Iteration 1492, loss = 0.14204070
# Iteration 1493, loss = 0.14199950
# Iteration 1494, loss = 0.14171169
# Iteration 1495, loss = 0.14158021
# Iteration 1496, loss = 0.14151282
# Iteration 1497, loss = 0.14146534
# Iteration 1498, loss = 0.14130344
# Iteration 1499, loss = 0.14115976
# Iteration 1500, loss = 0.14120193
# Iteration 1501, loss = 0.14112024
# Iteration 1502, loss = 0.14096777
# Iteration 1503, loss = 0.14090479
# Iteration 1504, loss = 0.14084419
# Iteration 1505, loss = 0.14076836
# Iteration 1506, loss = 0.14051879
# Iteration 1507, loss = 0.14045468
# Iteration 1508, loss = 0.14034216
# Iteration 1509, loss = 0.14027818
# Iteration 1510, loss = 0.14018069
# Iteration 1511, loss = 0.14007684
# Iteration 1512, loss = 0.13998755
# Iteration 1513, loss = 0.14009564
# Iteration 1514, loss = 0.13979232
# Iteration 1515, loss = 0.13970792
# Iteration 1516, loss = 0.13955682
# Iteration 1517, loss = 0.13949890
# Iteration 1518, loss = 0.13954315
# Iteration 1519, loss = 0.13944274
# Iteration 1520, loss = 0.13927696
# Iteration 1521, loss = 0.13919171
# Iteration 1522, loss = 0.13904313
# Iteration 1523, loss = 0.13922007
# Iteration 1524, loss = 0.13902113
# Iteration 1525, loss = 0.13905406
# Iteration 1526, loss = 0.13879730
# Iteration 1527, loss = 0.13871315
# Iteration 1528, loss = 0.13853137
# Iteration 1529, loss = 0.13878841
# Iteration 1530, loss = 0.13834232
# Iteration 1531, loss = 0.13829113
# Iteration 1532, loss = 0.13825359
# Iteration 1533, loss = 0.13807581
# Iteration 1534, loss = 0.13800440
# Iteration 1535, loss = 0.13841798
# Iteration 1536, loss = 0.13870727
# Iteration 1537, loss = 0.13779290
# Iteration 1538, loss = 0.13767357
# Iteration 1539, loss = 0.13770996
# Iteration 1540, loss = 0.13764603
# Iteration 1541, loss = 0.13738150
# Iteration 1542, loss = 0.13735867
# Iteration 1543, loss = 0.13723362
# Iteration 1544, loss = 0.13761503
# Iteration 1545, loss = 0.13726290
# Iteration 1546, loss = 0.13698904
# Iteration 1547, loss = 0.13705045
# Iteration 1548, loss = 0.13711861
# Iteration 1549, loss = 0.13677977
# Iteration 1550, loss = 0.13656727
# Iteration 1551, loss = 0.13649804
# Iteration 1552, loss = 0.13638088
# Iteration 1553, loss = 0.13633125
# Iteration 1554, loss = 0.13622302
# Iteration 1555, loss = 0.13614585
# Iteration 1556, loss = 0.13622051
# Iteration 1557, loss = 0.13602834
# Iteration 1558, loss = 0.13587812
# Iteration 1559, loss = 0.13595287
# Iteration 1560, loss = 0.13597348
# Iteration 1561, loss = 0.13587488
# Iteration 1562, loss = 0.13583961
# Iteration 1563, loss = 0.13533358
# Iteration 1564, loss = 0.13558813
# Iteration 1565, loss = 0.13571558
# Iteration 1566, loss = 0.13538027
# Iteration 1567, loss = 0.13569854
# Iteration 1568, loss = 0.13517552
# Iteration 1569, loss = 0.13545517
# Iteration 1570, loss = 0.13487279
# Iteration 1571, loss = 0.13496168
# Iteration 1572, loss = 0.13480347
# Iteration 1573, loss = 0.13470236
# Iteration 1574, loss = 0.13457507
# Iteration 1575, loss = 0.13445508
# Iteration 1576, loss = 0.13443880
# Iteration 1577, loss = 0.13421392
# Iteration 1578, loss = 0.13428922
# Iteration 1579, loss = 0.13408049
# Iteration 1580, loss = 0.13400100
# Iteration 1581, loss = 0.13390989
# Iteration 1582, loss = 0.13382668
# Iteration 1583, loss = 0.13361907
# Iteration 1584, loss = 0.13365833
# Iteration 1585, loss = 0.13355589
# Iteration 1586, loss = 0.13343715
# Iteration 1587, loss = 0.13334334
# Iteration 1588, loss = 0.13330781
# Iteration 1589, loss = 0.13407729
# Iteration 1590, loss = 0.13318782
# Iteration 1591, loss = 0.13308661
# Iteration 1592, loss = 0.13304711
# Iteration 1593, loss = 0.13313416
# Iteration 1594, loss = 0.13280550
# Iteration 1595, loss = 0.13294181
# Iteration 1596, loss = 0.13269725
# Iteration 1597, loss = 0.13249864
# Iteration 1598, loss = 0.13267340
# Iteration 1599, loss = 0.13239322
# Iteration 1600, loss = 0.13224516
# Iteration 1601, loss = 0.13222882
# Iteration 1602, loss = 0.13235344
# Iteration 1603, loss = 0.13209263
# Iteration 1604, loss = 0.13193471
# Iteration 1605, loss = 0.13233010
# Iteration 1606, loss = 0.13186966
# Iteration 1607, loss = 0.13170482
# Iteration 1608, loss = 0.13173184
# Iteration 1609, loss = 0.13159606
# Iteration 1610, loss = 0.13181705
# Iteration 1611, loss = 0.13136328
# Iteration 1612, loss = 0.13136000
# Iteration 1613, loss = 0.13145732
# Iteration 1614, loss = 0.13119522
# Iteration 1615, loss = 0.13145627
# Iteration 1616, loss = 0.13151074
# Iteration 1617, loss = 0.13093086
# Iteration 1618, loss = 0.13080751
# Iteration 1619, loss = 0.13090020
# Iteration 1620, loss = 0.13065734
# Iteration 1621, loss = 0.13066042
# Iteration 1622, loss = 0.13046578
# Iteration 1623, loss = 0.13039188
# Iteration 1624, loss = 0.13027563
# Iteration 1625, loss = 0.13028203
# Iteration 1626, loss = 0.13027292
# Iteration 1627, loss = 0.13032615
# Iteration 1628, loss = 0.13016270
# Iteration 1629, loss = 0.13002611
# Iteration 1630, loss = 0.13110184
# Iteration 1631, loss = 0.13006275
# Iteration 1632, loss = 0.13002746
# Iteration 1633, loss = 0.12982226
# Iteration 1634, loss = 0.12967294
# Iteration 1635, loss = 0.12955556
# Iteration 1636, loss = 0.12935160
# Iteration 1637, loss = 0.12961527
# Iteration 1638, loss = 0.12943470
# Iteration 1639, loss = 0.12911948
# Iteration 1640, loss = 0.12892365
# Iteration 1641, loss = 0.12889153
# Iteration 1642, loss = 0.12901724
# Iteration 1643, loss = 0.12871076
# Iteration 1644, loss = 0.12860432
# Iteration 1645, loss = 0.12866967
# Iteration 1646, loss = 0.12863872
# Iteration 1647, loss = 0.12837475
# Iteration 1648, loss = 0.12865232
# Iteration 1649, loss = 0.12826591
# Iteration 1650, loss = 0.12818398
# Iteration 1651, loss = 0.12813216
# Iteration 1652, loss = 0.12797558
# Iteration 1653, loss = 0.12782846
# Iteration 1654, loss = 0.12775618
# Iteration 1655, loss = 0.12774416
# Iteration 1656, loss = 0.12765469
# Iteration 1657, loss = 0.12767044
# Iteration 1658, loss = 0.12764438
# Iteration 1659, loss = 0.12750473
# Iteration 1660, loss = 0.12758754
# Iteration 1661, loss = 0.12718352
# Iteration 1662, loss = 0.12721930
# Iteration 1663, loss = 0.12730942
# Iteration 1664, loss = 0.12701148
# Iteration 1665, loss = 0.12689296
# Iteration 1666, loss = 0.12675239
# Iteration 1667, loss = 0.12670131
# Iteration 1668, loss = 0.12663861
# Iteration 1669, loss = 0.12683422
# Iteration 1670, loss = 0.12697555
# Iteration 1671, loss = 0.12646469
# Iteration 1672, loss = 0.12659425
# Iteration 1673, loss = 0.12728769
# Iteration 1674, loss = 0.12628640
# Iteration 1675, loss = 0.12698759
# Iteration 1676, loss = 0.12622845
# Iteration 1677, loss = 0.12623885
# Iteration 1678, loss = 0.12593907
# Iteration 1679, loss = 0.12595037
# Iteration 1680, loss = 0.12575654
# Iteration 1681, loss = 0.12568862
# Iteration 1682, loss = 0.12581709
# Iteration 1683, loss = 0.12569307
# Iteration 1684, loss = 0.12543881
# Iteration 1685, loss = 0.12529867
# Iteration 1686, loss = 0.12532181
# Iteration 1687, loss = 0.12521717
# Iteration 1688, loss = 0.12501618
# Iteration 1689, loss = 0.12507176
# Iteration 1690, loss = 0.12495701
# Iteration 1691, loss = 0.12504672
# Iteration 1692, loss = 0.12470185
# Iteration 1693, loss = 0.12478719
# Iteration 1694, loss = 0.12462522
# Iteration 1695, loss = 0.12481813
# Iteration 1696, loss = 0.12466319
# Iteration 1697, loss = 0.12434672
# Iteration 1698, loss = 0.12427000
# Iteration 1699, loss = 0.12432350
# Iteration 1700, loss = 0.12429727
# Iteration 1701, loss = 0.12405711
# Iteration 1702, loss = 0.12406562
# Iteration 1703, loss = 0.12392100
# Iteration 1704, loss = 0.12423130
# Iteration 1705, loss = 0.12372003
# Iteration 1706, loss = 0.12384161
# Iteration 1707, loss = 0.12360302
# Iteration 1708, loss = 0.12355690
# Iteration 1709, loss = 0.12347133
# Iteration 1710, loss = 0.12350421
# Iteration 1711, loss = 0.12328399
# Iteration 1712, loss = 0.12328659
# Iteration 1713, loss = 0.12334849
# Iteration 1714, loss = 0.12317345
# Iteration 1715, loss = 0.12314566
# Iteration 1716, loss = 0.12352975
# Iteration 1717, loss = 0.12322669
# Iteration 1718, loss = 0.12320564
# Iteration 1719, loss = 0.12289013
# Iteration 1720, loss = 0.12292774
# Iteration 1721, loss = 0.12255796
# Iteration 1722, loss = 0.12262877
# Iteration 1723, loss = 0.12241765
# Iteration 1724, loss = 0.12231298
# Iteration 1725, loss = 0.12234980
# Iteration 1726, loss = 0.12244171
# Iteration 1727, loss = 0.12261573
# Iteration 1728, loss = 0.12218529
# Iteration 1729, loss = 0.12200493
# Iteration 1730, loss = 0.12196923
# Iteration 1731, loss = 0.12182503
# Iteration 1732, loss = 0.12168965
# Iteration 1733, loss = 0.12169246
# Iteration 1734, loss = 0.12156017
# Iteration 1735, loss = 0.12149415
# Iteration 1736, loss = 0.12141075
# Iteration 1737, loss = 0.12128321
# Iteration 1738, loss = 0.12122205
# Iteration 1739, loss = 0.12127048
# Iteration 1740, loss = 0.12143189
# Iteration 1741, loss = 0.12091790
# Iteration 1742, loss = 0.12092095
# Iteration 1743, loss = 0.12114709
# Iteration 1744, loss = 0.12092509
# Iteration 1745, loss = 0.12071989
# Iteration 1746, loss = 0.12063860
# Iteration 1747, loss = 0.12079458
# Iteration 1748, loss = 0.12077191
# Iteration 1749, loss = 0.12053201
# Iteration 1750, loss = 0.12024876
# Iteration 1751, loss = 0.12055436
# Iteration 1752, loss = 0.12056472
# Iteration 1753, loss = 0.12012495
# Iteration 1754, loss = 0.12003297
# Iteration 1755, loss = 0.11995402
# Iteration 1756, loss = 0.11982168
# Iteration 1757, loss = 0.11984209
# Iteration 1758, loss = 0.11982932
# Iteration 1759, loss = 0.11965511
# Iteration 1760, loss = 0.11974517
# Iteration 1761, loss = 0.11952527
# Iteration 1762, loss = 0.11971192
# Iteration 1763, loss = 0.11937578
# Iteration 1764, loss = 0.11934184
# Iteration 1765, loss = 0.11931099
# Iteration 1766, loss = 0.11923360
# Iteration 1767, loss = 0.11911674
# Iteration 1768, loss = 0.11915810
# Iteration 1769, loss = 0.11892051
# Iteration 1770, loss = 0.11888033
# Iteration 1771, loss = 0.11883172
# Iteration 1772, loss = 0.11872073
# Iteration 1773, loss = 0.11857038
# Iteration 1774, loss = 0.11865729
# Iteration 1775, loss = 0.11862787
# Iteration 1776, loss = 0.11861630
# Iteration 1777, loss = 0.11831897
# Iteration 1778, loss = 0.11822111
# Iteration 1779, loss = 0.11818449
# Iteration 1780, loss = 0.11811653
# Iteration 1781, loss = 0.11797960
# Iteration 1782, loss = 0.11836860
# Iteration 1783, loss = 0.11797390
# Iteration 1784, loss = 0.11791667
# Iteration 1785, loss = 0.11774369
# Iteration 1786, loss = 0.11758878
# Iteration 1787, loss = 0.11764519
# Iteration 1788, loss = 0.11763746
# Iteration 1789, loss = 0.11743383
# Iteration 1790, loss = 0.11777902
# Iteration 1791, loss = 0.11741947
# Iteration 1792, loss = 0.11721799
# Iteration 1793, loss = 0.11734354
# Iteration 1794, loss = 0.11709338
# Iteration 1795, loss = 0.11712218
# Iteration 1796, loss = 0.11701557
# Iteration 1797, loss = 0.11688157
# Iteration 1798, loss = 0.11677085
# Iteration 1799, loss = 0.11665427
# Iteration 1800, loss = 0.11724792
# Iteration 1801, loss = 0.11654424
# Iteration 1802, loss = 0.11659341
# Iteration 1803, loss = 0.11647613
# Iteration 1804, loss = 0.11634952
# Iteration 1805, loss = 0.11618753
# Iteration 1806, loss = 0.11618925
# Iteration 1807, loss = 0.11637586
# Iteration 1808, loss = 0.11600534
# Iteration 1809, loss = 0.11601664
# Iteration 1810, loss = 0.11588793
# Iteration 1811, loss = 0.11592724
# Iteration 1812, loss = 0.11574988
# Iteration 1813, loss = 0.11574911
# Iteration 1814, loss = 0.11572035
# Iteration 1815, loss = 0.11564093
# Iteration 1816, loss = 0.11557570
# Iteration 1817, loss = 0.11560560
# Iteration 1818, loss = 0.11537739
# Iteration 1819, loss = 0.11529114
# Iteration 1820, loss = 0.11518439
# Iteration 1821, loss = 0.11523549
# Iteration 1822, loss = 0.11515754
# Iteration 1823, loss = 0.11505796
# Iteration 1824, loss = 0.11490236
# Iteration 1825, loss = 0.11551804
# Iteration 1826, loss = 0.11534379
# Iteration 1827, loss = 0.11472396
# Iteration 1828, loss = 0.11456572
# Iteration 1829, loss = 0.11446947
# Iteration 1830, loss = 0.11457168
# Iteration 1831, loss = 0.11469894
# Iteration 1832, loss = 0.11448898
# Iteration 1833, loss = 0.11431585
# Iteration 1834, loss = 0.11438489
# Iteration 1835, loss = 0.11414514
# Iteration 1836, loss = 0.11409066
# Iteration 1837, loss = 0.11400908
# Iteration 1838, loss = 0.11396937
# Iteration 1839, loss = 0.11384007
# Iteration 1840, loss = 0.11387418
# Iteration 1841, loss = 0.11370663
# Iteration 1842, loss = 0.11376756
# Iteration 1843, loss = 0.11355897
# Iteration 1844, loss = 0.11345720
# Iteration 1845, loss = 0.11349036
# Iteration 1846, loss = 0.11346001
# Iteration 1847, loss = 0.11333118
# Iteration 1848, loss = 0.11330166
# Iteration 1849, loss = 0.11319441
# Iteration 1850, loss = 0.11304160
# Iteration 1851, loss = 0.11296550
# Iteration 1852, loss = 0.11296884
# Iteration 1853, loss = 0.11286009
# Iteration 1854, loss = 0.11275870
# Iteration 1855, loss = 0.11289884
# Iteration 1856, loss = 0.11268239
# Iteration 1857, loss = 0.11288711
# Iteration 1858, loss = 0.11264340
# Iteration 1859, loss = 0.11258235
# Iteration 1860, loss = 0.11248310
# Iteration 1861, loss = 0.11243682
# Iteration 1862, loss = 0.11240164
# Iteration 1863, loss = 0.11246480
# Iteration 1864, loss = 0.11228372
# Iteration 1865, loss = 0.11211166
# Iteration 1866, loss = 0.11201518
# Iteration 1867, loss = 0.11202117
# Iteration 1868, loss = 0.11186378
# Iteration 1869, loss = 0.11179542
# Iteration 1870, loss = 0.11178065
# Iteration 1871, loss = 0.11200119
# Iteration 1872, loss = 0.11175839
# Iteration 1873, loss = 0.11146560
# Iteration 1874, loss = 0.11161745
# Iteration 1875, loss = 0.11137027
# Iteration 1876, loss = 0.11143960
# Iteration 1877, loss = 0.11125008
# Iteration 1878, loss = 0.11109348
# Iteration 1879, loss = 0.11132715
# Iteration 1880, loss = 0.11114425
# Iteration 1881, loss = 0.11125851
# Iteration 1882, loss = 0.11129146
# Iteration 1883, loss = 0.11105225
# Iteration 1884, loss = 0.11072216
# Iteration 1885, loss = 0.11085488
# Iteration 1886, loss = 0.11063460
# Iteration 1887, loss = 0.11065201
# Iteration 1888, loss = 0.11069809
# Iteration 1889, loss = 0.11114638
# Iteration 1890, loss = 0.11039144
# Iteration 1891, loss = 0.11031838
# Iteration 1892, loss = 0.11034472
# Iteration 1893, loss = 0.11023144
# Iteration 1894, loss = 0.11015896
# Iteration 1895, loss = 0.10998649
# Iteration 1896, loss = 0.10992046
# Iteration 1897, loss = 0.10986615
# Iteration 1898, loss = 0.10992429
# Iteration 1899, loss = 0.10978312
# Iteration 1900, loss = 0.10977873
# Iteration 1901, loss = 0.10966282
# Iteration 1902, loss = 0.10955444
# Iteration 1903, loss = 0.10954350
# Iteration 1904, loss = 0.10940608
# Iteration 1905, loss = 0.10943409
# Iteration 1906, loss = 0.10929510
# Iteration 1907, loss = 0.10923758
# Iteration 1908, loss = 0.10912640
# Iteration 1909, loss = 0.10964947
# Iteration 1910, loss = 0.10917682
# Iteration 1911, loss = 0.10889450
# Iteration 1912, loss = 0.10888597
# Iteration 1913, loss = 0.10898341
# Iteration 1914, loss = 0.10893930
# Iteration 1915, loss = 0.10873793
# Iteration 1916, loss = 0.10898329
# Iteration 1917, loss = 0.10886180
# Iteration 1918, loss = 0.10862243
# Iteration 1919, loss = 0.10848676
# Iteration 1920, loss = 0.10843785
# Iteration 1921, loss = 0.10833261
# Iteration 1922, loss = 0.10934978
# Iteration 1923, loss = 0.10822530
# Iteration 1924, loss = 0.10806537
# Iteration 1925, loss = 0.10808313
# Iteration 1926, loss = 0.10814683
# Iteration 1927, loss = 0.10836833
# Iteration 1928, loss = 0.10810337
# Iteration 1929, loss = 0.10780075
# Iteration 1930, loss = 0.10831600
# Iteration 1931, loss = 0.10754625
# Iteration 1932, loss = 0.10755802
# Iteration 1933, loss = 0.10782412
# Iteration 1934, loss = 0.10742536
# Iteration 1935, loss = 0.10743170
# Iteration 1936, loss = 0.10735220
# Iteration 1937, loss = 0.10721679
# Iteration 1938, loss = 0.10783890
# Iteration 1939, loss = 0.10736927
# Iteration 1940, loss = 0.10710984
# Iteration 1941, loss = 0.10696516
# Iteration 1942, loss = 0.10689823
# Iteration 1943, loss = 0.10692259
# Iteration 1944, loss = 0.10669148
# Iteration 1945, loss = 0.10677423
# Iteration 1946, loss = 0.10682356
# Iteration 1947, loss = 0.10670865
# Iteration 1948, loss = 0.10674270
# Iteration 1949, loss = 0.10640965
# Iteration 1950, loss = 0.10674097
# Iteration 1951, loss = 0.10631527
# Iteration 1952, loss = 0.10663227
# Iteration 1953, loss = 0.10623989
# Iteration 1954, loss = 0.10609864
# Iteration 1955, loss = 0.10660093
# Iteration 1956, loss = 0.10653464
# Iteration 1957, loss = 0.10589448
# Iteration 1958, loss = 0.10606340
# Iteration 1959, loss = 0.10625072
# Iteration 1960, loss = 0.10582872
# Iteration 1961, loss = 0.10576997
# Iteration 1962, loss = 0.10564201
# Iteration 1963, loss = 0.10585758
# Iteration 1964, loss = 0.10543773
# Iteration 1965, loss = 0.10539479
# Iteration 1966, loss = 0.10535723
# Iteration 1967, loss = 0.10539958
# Iteration 1968, loss = 0.10525447
# Iteration 1969, loss = 0.10530733
# Iteration 1970, loss = 0.10511163
# Iteration 1971, loss = 0.10519623
# Iteration 1972, loss = 0.10510899
# Iteration 1973, loss = 0.10491247
# Iteration 1974, loss = 0.10482819
# Iteration 1975, loss = 0.10484619
# Iteration 1976, loss = 0.10469994
# Iteration 1977, loss = 0.10484293
# Iteration 1978, loss = 0.10460707
# Iteration 1979, loss = 0.10465789
# Iteration 1980, loss = 0.10444893
# Iteration 1981, loss = 0.10443007
# Iteration 1982, loss = 0.10443771
# Iteration 1983, loss = 0.10451923
# Iteration 1984, loss = 0.10433557
# Iteration 1985, loss = 0.10459707
# Iteration 1986, loss = 0.10416380
# Iteration 1987, loss = 0.10393047
# Iteration 1988, loss = 0.10396832
# Iteration 1989, loss = 0.10401295
# Iteration 1990, loss = 0.10427950
# Iteration 1991, loss = 0.10380638
# Iteration 1992, loss = 0.10380027
# Iteration 1993, loss = 0.10413420
# Iteration 1994, loss = 0.10364444
# Iteration 1995, loss = 0.10374820
# Iteration 1996, loss = 0.10356218
# Iteration 1997, loss = 0.10351771
# Iteration 1998, loss = 0.10328021
# Iteration 1999, loss = 0.10330867
# Iteration 2000, loss = 0.10325762
# Training Neural Network (Medium)...
# Iteration 1, loss = 0.75925653
# Iteration 2, loss = 0.72432335
# Iteration 3, loss = 0.69314018
# Iteration 4, loss = 0.66831526
# Iteration 5, loss = 0.64641237
# Iteration 6, loss = 0.62800904
# Iteration 7, loss = 0.61522347
# Iteration 8, loss = 0.60414275
# Iteration 9, loss = 0.59551363
# Iteration 10, loss = 0.58871409
# Iteration 11, loss = 0.58499809
# Iteration 12, loss = 0.58286472
# Iteration 13, loss = 0.57972888
# Iteration 14, loss = 0.57792269
# Iteration 15, loss = 0.57709013
# Iteration 16, loss = 0.57549250
# Iteration 17, loss = 0.57388494
# Iteration 18, loss = 0.57201952
# Iteration 19, loss = 0.57006095
# Iteration 20, loss = 0.56781104
# Iteration 21, loss = 0.56572980
# Iteration 22, loss = 0.56333261
# Iteration 23, loss = 0.56079129
# Iteration 24, loss = 0.55856957
# Iteration 25, loss = 0.55641641
# Iteration 26, loss = 0.55418321
# Iteration 27, loss = 0.55230547
# Iteration 28, loss = 0.54990385
# Iteration 29, loss = 0.54797919
# Iteration 30, loss = 0.54593646
# Iteration 31, loss = 0.54418250
# Iteration 32, loss = 0.54227001
# Iteration 33, loss = 0.54025050
# Iteration 34, loss = 0.53829069
# Iteration 35, loss = 0.53631571
# Iteration 36, loss = 0.53420450
# Iteration 37, loss = 0.53231479
# Iteration 38, loss = 0.53022600
# Iteration 39, loss = 0.52817094
# Iteration 40, loss = 0.52620236
# Iteration 41, loss = 0.52436926
# Iteration 42, loss = 0.52220024
# Iteration 43, loss = 0.52020377
# Iteration 44, loss = 0.51800102
# Iteration 45, loss = 0.51601563
# Iteration 46, loss = 0.51409242
# Iteration 47, loss = 0.51191766
# Iteration 48, loss = 0.50990436
# Iteration 49, loss = 0.50787038
# Iteration 50, loss = 0.50588111
# Iteration 51, loss = 0.50392208
# Iteration 52, loss = 0.50191960
# Iteration 53, loss = 0.49987937
# Iteration 54, loss = 0.49796335
# Iteration 55, loss = 0.49603879
# Iteration 56, loss = 0.49401007
# Iteration 57, loss = 0.49204480
# Iteration 58, loss = 0.49024167
# Iteration 59, loss = 0.48830421
# Iteration 60, loss = 0.48638606
# Iteration 61, loss = 0.48448654
# Iteration 62, loss = 0.48250260
# Iteration 63, loss = 0.48071573
# Iteration 64, loss = 0.47889619
# Iteration 65, loss = 0.47694465
# Iteration 66, loss = 0.47519972
# Iteration 67, loss = 0.47344752
# Iteration 68, loss = 0.47166803
# Iteration 69, loss = 0.46999387
# Iteration 70, loss = 0.46818358
# Iteration 71, loss = 0.46650612
# Iteration 72, loss = 0.46488929
# Iteration 73, loss = 0.46313609
# Iteration 74, loss = 0.46149145
# Iteration 75, loss = 0.45979205
# Iteration 76, loss = 0.45824867
# Iteration 77, loss = 0.45661750
# Iteration 78, loss = 0.45500401
# Iteration 79, loss = 0.45356026
# Iteration 80, loss = 0.45189222
# Iteration 81, loss = 0.45046650
# Iteration 82, loss = 0.44893707
# Iteration 83, loss = 0.44735743
# Iteration 84, loss = 0.44592299
# Iteration 85, loss = 0.44452390
# Iteration 86, loss = 0.44309199
# Iteration 87, loss = 0.44160221
# Iteration 88, loss = 0.44017078
# Iteration 89, loss = 0.43878206
# Iteration 90, loss = 0.43748295
# Iteration 91, loss = 0.43615167
# Iteration 92, loss = 0.43472124
# Iteration 93, loss = 0.43330624
# Iteration 94, loss = 0.43199821
# Iteration 95, loss = 0.43063098
# Iteration 96, loss = 0.42939231
# Iteration 97, loss = 0.42810566
# Iteration 98, loss = 0.42694275
# Iteration 99, loss = 0.42589643
# Iteration 100, loss = 0.42453842
# Iteration 101, loss = 0.42329112
# Iteration 102, loss = 0.42222226
# Iteration 103, loss = 0.42099363
# Iteration 104, loss = 0.41991821
# Iteration 105, loss = 0.41889668
# Iteration 106, loss = 0.41773423
# Iteration 107, loss = 0.41675312
# Iteration 108, loss = 0.41570306
# Iteration 109, loss = 0.41489625
# Iteration 110, loss = 0.41369415
# Iteration 111, loss = 0.41267723
# Iteration 112, loss = 0.41188849
# Iteration 113, loss = 0.41087000
# Iteration 114, loss = 0.40992945
# Iteration 115, loss = 0.40898189
# Iteration 116, loss = 0.40812862
# Iteration 117, loss = 0.40725357
# Iteration 118, loss = 0.40643568
# Iteration 119, loss = 0.40536239
# Iteration 120, loss = 0.40449658
# Iteration 121, loss = 0.40365545
# Iteration 122, loss = 0.40282271
# Iteration 123, loss = 0.40204699
# Iteration 124, loss = 0.40119962
# Iteration 125, loss = 0.40047395
# Iteration 126, loss = 0.39954594
# Iteration 127, loss = 0.39875755
# Iteration 128, loss = 0.39805169
# Iteration 129, loss = 0.39735913
# Iteration 130, loss = 0.39652803
# Iteration 131, loss = 0.39580261
# Iteration 132, loss = 0.39501967
# Iteration 133, loss = 0.39425815
# Iteration 134, loss = 0.39358312
# Iteration 135, loss = 0.39289225
# Iteration 136, loss = 0.39222762
# Iteration 137, loss = 0.39150402
# Iteration 138, loss = 0.39091203
# Iteration 139, loss = 0.39031466
# Iteration 140, loss = 0.38946917
# Iteration 141, loss = 0.38897673
# Iteration 142, loss = 0.38822991
# Iteration 143, loss = 0.38765174
# Iteration 144, loss = 0.38700972
# Iteration 145, loss = 0.38630497
# Iteration 146, loss = 0.38565501
# Iteration 147, loss = 0.38505264
# Iteration 148, loss = 0.38440655
# Iteration 149, loss = 0.38379788
# Iteration 150, loss = 0.38318206
# Iteration 151, loss = 0.38252265
# Iteration 152, loss = 0.38207515
# Iteration 153, loss = 0.38138533
# Iteration 154, loss = 0.38074263
# Iteration 155, loss = 0.38025193
# Iteration 156, loss = 0.37967605
# Iteration 157, loss = 0.37900478
# Iteration 158, loss = 0.37850902
# Iteration 159, loss = 0.37798151
# Iteration 160, loss = 0.37735927
# Iteration 161, loss = 0.37682043
# Iteration 162, loss = 0.37653695
# Iteration 163, loss = 0.37577178
# Iteration 164, loss = 0.37525431
# Iteration 165, loss = 0.37469959
# Iteration 166, loss = 0.37438802
# Iteration 167, loss = 0.37372342
# Iteration 168, loss = 0.37331024
# Iteration 169, loss = 0.37274630
# Iteration 170, loss = 0.37223729
# Iteration 171, loss = 0.37183327
# Iteration 172, loss = 0.37121793
# Iteration 173, loss = 0.37071511
# Iteration 174, loss = 0.37021796
# Iteration 175, loss = 0.36977825
# Iteration 176, loss = 0.36924778
# Iteration 177, loss = 0.36878857
# Iteration 178, loss = 0.36836319
# Iteration 179, loss = 0.36792778
# Iteration 180, loss = 0.36744832
# Iteration 181, loss = 0.36709606
# Iteration 182, loss = 0.36652679
# Iteration 183, loss = 0.36604663
# Iteration 184, loss = 0.36567880
# Iteration 185, loss = 0.36537761
# Iteration 186, loss = 0.36488811
# Iteration 187, loss = 0.36448150
# Iteration 188, loss = 0.36393907
# Iteration 189, loss = 0.36354028
# Iteration 190, loss = 0.36307022
# Iteration 191, loss = 0.36268348
# Iteration 192, loss = 0.36231526
# Iteration 193, loss = 0.36190849
# Iteration 194, loss = 0.36156682
# Iteration 195, loss = 0.36109150
# Iteration 196, loss = 0.36065079
# Iteration 197, loss = 0.36046289
# Iteration 198, loss = 0.36016758
# Iteration 199, loss = 0.35950195
# Iteration 200, loss = 0.35915712
# Iteration 201, loss = 0.35869693
# Iteration 202, loss = 0.35862420
# Iteration 203, loss = 0.35800042
# Iteration 204, loss = 0.35764239
# Iteration 205, loss = 0.35733885
# Iteration 206, loss = 0.35693586
# Iteration 207, loss = 0.35647838
# Iteration 208, loss = 0.35621087
# Iteration 209, loss = 0.35584926
# Iteration 210, loss = 0.35533755
# Iteration 211, loss = 0.35506772
# Iteration 212, loss = 0.35472883
# Iteration 213, loss = 0.35427278
# Iteration 214, loss = 0.35391333
# Iteration 215, loss = 0.35371944
# Iteration 216, loss = 0.35325737
# Iteration 217, loss = 0.35277253
# Iteration 218, loss = 0.35243110
# Iteration 219, loss = 0.35233216
# Iteration 220, loss = 0.35176642
# Iteration 221, loss = 0.35138929
# Iteration 222, loss = 0.35105719
# Iteration 223, loss = 0.35073499
# Iteration 224, loss = 0.35044607
# Iteration 225, loss = 0.35001115
# Iteration 226, loss = 0.34968526
# Iteration 227, loss = 0.34941916
# Iteration 228, loss = 0.34903740
# Iteration 229, loss = 0.34867448
# Iteration 230, loss = 0.34842336
# Iteration 231, loss = 0.34805919
# Iteration 232, loss = 0.34767557
# Iteration 233, loss = 0.34742848
# Iteration 234, loss = 0.34701320
# Iteration 235, loss = 0.34663611
# Iteration 236, loss = 0.34642027
# Iteration 237, loss = 0.34597500
# Iteration 238, loss = 0.34560312
# Iteration 239, loss = 0.34542883
# Iteration 240, loss = 0.34513857
# Iteration 241, loss = 0.34470718
# Iteration 242, loss = 0.34431822
# Iteration 243, loss = 0.34394659
# Iteration 244, loss = 0.34362011
# Iteration 245, loss = 0.34346750
# Iteration 246, loss = 0.34300371
# Iteration 247, loss = 0.34278891
# Iteration 248, loss = 0.34229032
# Iteration 249, loss = 0.34244613
# Iteration 250, loss = 0.34171429
# Iteration 251, loss = 0.34139344
# Iteration 252, loss = 0.34112862
# Iteration 253, loss = 0.34088177
# Iteration 254, loss = 0.34044271
# Iteration 255, loss = 0.34006299
# Iteration 256, loss = 0.33973416
# Iteration 257, loss = 0.33936024
# Iteration 258, loss = 0.33900914
# Iteration 259, loss = 0.33896650
# Iteration 260, loss = 0.33841212
# Iteration 261, loss = 0.33807453
# Iteration 262, loss = 0.33844112
# Iteration 263, loss = 0.33751795
# ...
# Iteration 1370, loss = 0.12816591
# Iteration 1371, loss = 0.12825711
# Iteration 1372, loss = 0.12810277
# Iteration 1373, loss = 0.12791045
# Iteration 1374, loss = 0.12800964
# Iteration 1375, loss = 0.12786867
# Iteration 1376, loss = 0.12774537
# Iteration 1377, loss = 0.12776608
# Iteration 1378, loss = 0.12763018
# Iteration 1379, loss = 0.12744840
# Iteration 1380, loss = 0.12743850
# Iteration 1381, loss = 0.12735879
# Iteration 1382, loss = 0.12728316
# Iteration 1383, loss = 0.12724136
# Iteration 1384, loss = 0.12710733
# Iteration 1385, loss = 0.12683536
# Iteration 1386, loss = 0.12783956
# Iteration 1387, loss = 0.12710719
# Iteration 1388, loss = 0.12715011
# Iteration 1389, loss = 0.12686062
# Iteration 1390, loss = 0.12666835
# Iteration 1391, loss = 0.12717254
# Iteration 1392, loss = 0.12657993
# Iteration 1393, loss = 0.12652953
# Iteration 1394, loss = 0.12611846
# Iteration 1395, loss = 0.12627871
# Iteration 1396, loss = 0.12623563
# Iteration 1397, loss = 0.12600427
# Iteration 1398, loss = 0.12591878
# Iteration 1399, loss = 0.12603930
# Iteration 1400, loss = 0.12570919
# Iteration 1401, loss = 0.12553450
# Iteration 1402, loss = 0.12599631
# Iteration 1403, loss = 0.12561211
# Iteration 1404, loss = 0.12538791
# Iteration 1405, loss = 0.12547334
# Iteration 1406, loss = 0.12551709
# Iteration 1407, loss = 0.12521634
# Iteration 1408, loss = 0.12504597
# Iteration 1409, loss = 0.12500728
# Iteration 1410, loss = 0.12487324
# Iteration 1411, loss = 0.12486688
# Iteration 1412, loss = 0.12488789
# Iteration 1413, loss = 0.12460910
# Iteration 1414, loss = 0.12455276
# Iteration 1415, loss = 0.12446915
# Iteration 1416, loss = 0.12444756
# Iteration 1417, loss = 0.12444898
# Iteration 1418, loss = 0.12438868
# Iteration 1419, loss = 0.12437678
# Iteration 1420, loss = 0.12444048
# Iteration 1421, loss = 0.12411125
# Iteration 1422, loss = 0.12400534
# Iteration 1423, loss = 0.12395358
# Iteration 1424, loss = 0.12381587
# Iteration 1425, loss = 0.12363694
# Iteration 1426, loss = 0.12389316
# Iteration 1427, loss = 0.12357673
# Iteration 1428, loss = 0.12346358
# Iteration 1429, loss = 0.12328857
# Iteration 1430, loss = 0.12383375
# Iteration 1431, loss = 0.12325666
# Iteration 1432, loss = 0.12313532
# Iteration 1433, loss = 0.12378803
# Iteration 1434, loss = 0.12310448
# Iteration 1435, loss = 0.12308748
# Iteration 1436, loss = 0.12287788
# Iteration 1437, loss = 0.12280299
# Iteration 1438, loss = 0.12303588
# Iteration 1439, loss = 0.12324200
# Iteration 1440, loss = 0.12251582
# Iteration 1441, loss = 0.12277429
# Iteration 1442, loss = 0.12247317
# Iteration 1443, loss = 0.12233209
# Iteration 1444, loss = 0.12223521
# Iteration 1445, loss = 0.12229138
# Iteration 1446, loss = 0.12198770
# Iteration 1447, loss = 0.12190220
# Iteration 1448, loss = 0.12179263
# Iteration 1449, loss = 0.12217497
# Iteration 1450, loss = 0.12196558
# Iteration 1451, loss = 0.12165644
# Iteration 1452, loss = 0.12150694
# Iteration 1453, loss = 0.12174457
# Iteration 1454, loss = 0.12131063
# Iteration 1455, loss = 0.12126667
# Iteration 1456, loss = 0.12121533
# Iteration 1457, loss = 0.12124606
# Iteration 1458, loss = 0.12105295
# Iteration 1459, loss = 0.12099053
# Iteration 1460, loss = 0.12098286
# Iteration 1461, loss = 0.12092122
# Iteration 1462, loss = 0.12088526
# Iteration 1463, loss = 0.12111535
# Iteration 1464, loss = 0.12077204
# Iteration 1465, loss = 0.12050905
# Iteration 1466, loss = 0.12034007
# Iteration 1467, loss = 0.12028399
# Iteration 1468, loss = 0.12020934
# Iteration 1469, loss = 0.12013620
# Iteration 1470, loss = 0.12016933
# Iteration 1471, loss = 0.12020626
# Iteration 1472, loss = 0.11989182
# Iteration 1473, loss = 0.11990065
# Iteration 1474, loss = 0.12000129
# Iteration 1475, loss = 0.11981173
# Iteration 1476, loss = 0.11970262
# Iteration 1477, loss = 0.11952598
# Iteration 1478, loss = 0.11943724
# Iteration 1479, loss = 0.11941857
# Iteration 1480, loss = 0.11938539
# Iteration 1481, loss = 0.11921441
# Iteration 1482, loss = 0.11934914
# Iteration 1483, loss = 0.11912469
# Iteration 1484, loss = 0.11897007
# Iteration 1485, loss = 0.11905850
# Iteration 1486, loss = 0.11885066
# Iteration 1487, loss = 0.11888944
# Iteration 1488, loss = 0.11871068
# Iteration 1489, loss = 0.11862586
# Iteration 1490, loss = 0.11847692
# Iteration 1491, loss = 0.11843216
# Iteration 1492, loss = 0.11845251
# Iteration 1493, loss = 0.11831493
# Iteration 1494, loss = 0.11842734
# Iteration 1495, loss = 0.11847998
# Iteration 1496, loss = 0.11813734
# Iteration 1497, loss = 0.11801146
# Iteration 1498, loss = 0.11792135
# Iteration 1499, loss = 0.11798228
# Iteration 1500, loss = 0.11809000
# Iteration 1501, loss = 0.11767948
# Iteration 1502, loss = 0.11833535
# Iteration 1503, loss = 0.11780226
# Iteration 1504, loss = 0.11786322
# Iteration 1505, loss = 0.11765945
# Iteration 1506, loss = 0.11738181
# Iteration 1507, loss = 0.11758383
# Iteration 1508, loss = 0.11747234
# Iteration 1509, loss = 0.11736680
# Iteration 1510, loss = 0.11709315
# Iteration 1511, loss = 0.11713676
# Iteration 1512, loss = 0.11699779
# Iteration 1513, loss = 0.11679634
# Iteration 1514, loss = 0.11668998
# Iteration 1515, loss = 0.11670826
# Iteration 1516, loss = 0.11678882
# Iteration 1517, loss = 0.11653328
# Iteration 1518, loss = 0.11659178
# Iteration 1519, loss = 0.11634134
# Iteration 1520, loss = 0.11694310
# Iteration 1521, loss = 0.11627322
# Iteration 1522, loss = 0.11615729
# Iteration 1523, loss = 0.11624150
# Iteration 1524, loss = 0.11621627
# Iteration 1525, loss = 0.11585378
# Iteration 1526, loss = 0.11593292
# Iteration 1527, loss = 0.11596851
# Iteration 1528, loss = 0.11577414
# Iteration 1529, loss = 0.11577292
# Iteration 1530, loss = 0.11575882
# Iteration 1531, loss = 0.11561788
# Iteration 1532, loss = 0.11547914
# Iteration 1533, loss = 0.11570565
# Iteration 1534, loss = 0.11543259
# Iteration 1535, loss = 0.11522020
# Iteration 1536, loss = 0.11551196
# Iteration 1537, loss = 0.11524665
# Iteration 1538, loss = 0.11503621
# Iteration 1539, loss = 0.11500172
# Iteration 1540, loss = 0.11505298
# Iteration 1541, loss = 0.11491895
# Iteration 1542, loss = 0.11484799
# Iteration 1543, loss = 0.11530071
# Iteration 1544, loss = 0.11511238
# Iteration 1545, loss = 0.11472688
# Iteration 1546, loss = 0.11453468
# Iteration 1547, loss = 0.11433847
# Iteration 1548, loss = 0.11443756
# Iteration 1549, loss = 0.11427865
# Iteration 1550, loss = 0.11418411
# Iteration 1551, loss = 0.11410533
# Iteration 1552, loss = 0.11406232
# Iteration 1553, loss = 0.11403538
# Iteration 1554, loss = 0.11382667
# Iteration 1555, loss = 0.11382465
# Iteration 1556, loss = 0.11396167
# Iteration 1557, loss = 0.11361388
# Iteration 1558, loss = 0.11369273
# Iteration 1559, loss = 0.11353408
# Iteration 1560, loss = 0.11342419
# Iteration 1561, loss = 0.11340295
# Iteration 1562, loss = 0.11346882
# Iteration 1563, loss = 0.11334553
# Iteration 1564, loss = 0.11330994
# Iteration 1565, loss = 0.11326034
# Iteration 1566, loss = 0.11306864
# Iteration 1567, loss = 0.11317281
# Iteration 1568, loss = 0.11292591
# Iteration 1569, loss = 0.11336573
# Iteration 1570, loss = 0.11293401
# Iteration 1571, loss = 0.11277315
# Iteration 1572, loss = 0.11265235
# Iteration 1573, loss = 0.11258006
# Iteration 1574, loss = 0.11266084
# Iteration 1575, loss = 0.11253667
# Iteration 1576, loss = 0.11229321
# Iteration 1577, loss = 0.11231921
# Iteration 1578, loss = 0.11263209
# Iteration 1579, loss = 0.11207352
# Iteration 1580, loss = 0.11227556
# Iteration 1581, loss = 0.11214953
# Iteration 1582, loss = 0.11207864
# Iteration 1583, loss = 0.11185208
# Iteration 1584, loss = 0.11191252
# Iteration 1585, loss = 0.11175516
# Iteration 1586, loss = 0.11204593
# Iteration 1587, loss = 0.11155123
# Iteration 1588, loss = 0.11149263
# Iteration 1589, loss = 0.11168217
# Iteration 1590, loss = 0.11139436
# Iteration 1591, loss = 0.11127475
# Iteration 1592, loss = 0.11138890
# Iteration 1593, loss = 0.11122102
# Iteration 1594, loss = 0.11101288
# Iteration 1595, loss = 0.11106902
# Iteration 1596, loss = 0.11123413
# Iteration 1597, loss = 0.11097367
# Iteration 1598, loss = 0.11104459
# Iteration 1599, loss = 0.11068514
# Iteration 1600, loss = 0.11070630
# Iteration 1601, loss = 0.11071965
# Iteration 1602, loss = 0.11054355
# Iteration 1603, loss = 0.11115241
# Iteration 1604, loss = 0.11037984
# Iteration 1605, loss = 0.11058318
# Iteration 1606, loss = 0.11047190
# Iteration 1607, loss = 0.11028407
# Iteration 1608, loss = 0.11044917
# Iteration 1609, loss = 0.11026437
# Iteration 1610, loss = 0.11005267
# Iteration 1611, loss = 0.10990231
# Iteration 1612, loss = 0.11002005
# Iteration 1613, loss = 0.10983726
# Iteration 1614, loss = 0.10978961
# Iteration 1615, loss = 0.10988398
# Iteration 1616, loss = 0.10960787
# Iteration 1617, loss = 0.10958416
# Iteration 1618, loss = 0.10938258
# Iteration 1619, loss = 0.10954845
# Iteration 1620, loss = 0.10960067
# Iteration 1621, loss = 0.10926293
# Iteration 1622, loss = 0.10928518
# Iteration 1623, loss = 0.10907164
# Iteration 1624, loss = 0.10913016
# Iteration 1625, loss = 0.10901762
# Iteration 1626, loss = 0.10888703
# Iteration 1627, loss = 0.10897879
# Iteration 1628, loss = 0.10885915
# Iteration 1629, loss = 0.10873061
# Iteration 1630, loss = 0.10871982
# Iteration 1631, loss = 0.10873160
# Iteration 1632, loss = 0.10856301
# Iteration 1633, loss = 0.10847933
# Iteration 1634, loss = 0.10837248
# Iteration 1635, loss = 0.10830866
# Iteration 1636, loss = 0.10857443
# Iteration 1637, loss = 0.10818287
# Iteration 1638, loss = 0.10873228
# Iteration 1639, loss = 0.10803533
# Iteration 1640, loss = 0.10806635
# Iteration 1641, loss = 0.10799499
# Iteration 1642, loss = 0.10790518
# Iteration 1643, loss = 0.10842726
# Iteration 1644, loss = 0.10766248
# Iteration 1645, loss = 0.10768007
# Iteration 1646, loss = 0.10763897
# Iteration 1647, loss = 0.10762243
# Iteration 1648, loss = 0.10750433
# Iteration 1649, loss = 0.10735904
# Iteration 1650, loss = 0.10734172
# Iteration 1651, loss = 0.10740486
# Iteration 1652, loss = 0.10718693
# Iteration 1653, loss = 0.10707366
# Iteration 1654, loss = 0.10708205
# Iteration 1655, loss = 0.10700397
# Iteration 1656, loss = 0.10691860
# Iteration 1657, loss = 0.10692431
# Iteration 1658, loss = 0.10679703
# Iteration 1659, loss = 0.10683687
# Iteration 1660, loss = 0.10677909
# Iteration 1661, loss = 0.10662205
# Iteration 1662, loss = 0.10670135
# Iteration 1663, loss = 0.10646495
# Iteration 1664, loss = 0.10652404
# Iteration 1665, loss = 0.10669700
# Iteration 1666, loss = 0.10629888
# Iteration 1667, loss = 0.10654254
# Iteration 1668, loss = 0.10641135
# Iteration 1669, loss = 0.10625299
# Iteration 1670, loss = 0.10611373
# Iteration 1671, loss = 0.10592535
# Iteration 1672, loss = 0.10592514
# Iteration 1673, loss = 0.10625444
# Iteration 1674, loss = 0.10571421
# Iteration 1675, loss = 0.10575435
# Iteration 1676, loss = 0.10581388
# Iteration 1677, loss = 0.10571354
# Iteration 1678, loss = 0.10556974
# Iteration 1679, loss = 0.10564471
# Iteration 1680, loss = 0.10550266
# Iteration 1681, loss = 0.10543465
# Iteration 1682, loss = 0.10526389
# Iteration 1683, loss = 0.10515981
# Iteration 1684, loss = 0.10512318
# Iteration 1685, loss = 0.10504066
# Iteration 1686, loss = 0.10511843
# Iteration 1687, loss = 0.10492450
# Iteration 1688, loss = 0.10489610
# Iteration 1689, loss = 0.10481694
# Iteration 1690, loss = 0.10508164
# Iteration 1691, loss = 0.10469778
# Iteration 1692, loss = 0.10468377
# Iteration 1693, loss = 0.10465520
# Iteration 1694, loss = 0.10461572
# Iteration 1695, loss = 0.10458820
# Iteration 1696, loss = 0.10483255
# Iteration 1697, loss = 0.10434987
# Iteration 1698, loss = 0.10418772
# Iteration 1699, loss = 0.10421300
# Iteration 1700, loss = 0.10423943
# Iteration 1701, loss = 0.10402488
# Iteration 1702, loss = 0.10455827
# Iteration 1703, loss = 0.10415502
# Iteration 1704, loss = 0.10391502
# Iteration 1705, loss = 0.10381335
# Iteration 1706, loss = 0.10386584
# Iteration 1707, loss = 0.10398963
# Iteration 1708, loss = 0.10376950
# Iteration 1709, loss = 0.10358324
# Iteration 1710, loss = 0.10356579
# Iteration 1711, loss = 0.10350896
# Iteration 1712, loss = 0.10421810
# Iteration 1713, loss = 0.10332092
# Iteration 1714, loss = 0.10344473
# Iteration 1715, loss = 0.10357101
# Iteration 1716, loss = 0.10322515
# Iteration 1717, loss = 0.10306309
# Iteration 1718, loss = 0.10307187
# Iteration 1719, loss = 0.10325313
# Iteration 1720, loss = 0.10305246
# Iteration 1721, loss = 0.10287716
# Iteration 1722, loss = 0.10326943
# Iteration 1723, loss = 0.10311936
# Iteration 1724, loss = 0.10274878
# Iteration 1725, loss = 0.10280076
# Iteration 1726, loss = 0.10349509
# Iteration 1727, loss = 0.10294462
# Iteration 1728, loss = 0.10230551
# Iteration 1729, loss = 0.10241288
# Iteration 1730, loss = 0.10293357
# Iteration 1731, loss = 0.10261159
# Iteration 1732, loss = 0.10226971
# Iteration 1733, loss = 0.10221617
# Iteration 1734, loss = 0.10226975
# Iteration 1735, loss = 0.10226287
# Iteration 1736, loss = 0.10204561
# Iteration 1737, loss = 0.10233360
# Iteration 1738, loss = 0.10230298
# Iteration 1739, loss = 0.10185251
# Iteration 1740, loss = 0.10173983
# Iteration 1741, loss = 0.10183824
# Iteration 1742, loss = 0.10200722
# Iteration 1743, loss = 0.10187998
# Iteration 1744, loss = 0.10184072
# Iteration 1745, loss = 0.10133276
# Iteration 1746, loss = 0.10132644
# Iteration 1747, loss = 0.10120188
# Iteration 1748, loss = 0.10117252
# Iteration 1749, loss = 0.10119393
# Iteration 1750, loss = 0.10118438
# Iteration 1751, loss = 0.10104633
# Iteration 1752, loss = 0.10092148
# Iteration 1753, loss = 0.10083096
# Iteration 1754, loss = 0.10104100
# Iteration 1755, loss = 0.10100976
# Iteration 1756, loss = 0.10074805
# Iteration 1757, loss = 0.10064522
# Iteration 1758, loss = 0.10095562
# Iteration 1759, loss = 0.10054680
# Iteration 1760, loss = 0.10069751
# Iteration 1761, loss = 0.10054121
# Iteration 1762, loss = 0.10028520
# Iteration 1763, loss = 0.10030983
# Iteration 1764, loss = 0.10012502
# Iteration 1765, loss = 0.10030802
# Iteration 1766, loss = 0.10019582
# Iteration 1767, loss = 0.09997874
# Iteration 1768, loss = 0.09992769
# Iteration 1769, loss = 0.09992728
# Iteration 1770, loss = 0.09985811
# Iteration 1771, loss = 0.09980826
# Iteration 1772, loss = 0.09962864
# Iteration 1773, loss = 0.09975714
# Iteration 1774, loss = 0.09966383
# Iteration 1775, loss = 0.09945899
# Iteration 1776, loss = 0.09952171
# Iteration 1777, loss = 0.09971351
# Iteration 1778, loss = 0.09955041
# Iteration 1779, loss = 0.09914475
# Iteration 1780, loss = 0.09916129
# Iteration 1781, loss = 0.09918466
# Iteration 1782, loss = 0.09937216
# Iteration 1783, loss = 0.09900551
# Iteration 1784, loss = 0.09902871
# Iteration 1785, loss = 0.09913306
# Iteration 1786, loss = 0.09890727
# Iteration 1787, loss = 0.09884262
# Iteration 1788, loss = 0.09879720
# Iteration 1789, loss = 0.09875057
# Iteration 1790, loss = 0.09853049
# Iteration 1791, loss = 0.09844310
# Iteration 1792, loss = 0.09831860
# Iteration 1793, loss = 0.09828948
# Iteration 1794, loss = 0.09823460
# Iteration 1795, loss = 0.09848959
# Iteration 1796, loss = 0.09818030
# Iteration 1797, loss = 0.09839452
# Iteration 1798, loss = 0.09795829
# Iteration 1799, loss = 0.09802442
# Iteration 1800, loss = 0.09787843
# Iteration 1801, loss = 0.09776676
# Iteration 1802, loss = 0.09803492
# Iteration 1803, loss = 0.09760568
# Iteration 1804, loss = 0.09761898
# Iteration 1805, loss = 0.09754918
# Iteration 1806, loss = 0.09748165
# Iteration 1807, loss = 0.09911444
# Iteration 1808, loss = 0.09754549
# Iteration 1809, loss = 0.09728753
# Iteration 1810, loss = 0.09724017
# Iteration 1811, loss = 0.09738312
# Iteration 1812, loss = 0.09714895
# Iteration 1813, loss = 0.09746423
# Iteration 1814, loss = 0.09733519
# Iteration 1815, loss = 0.09720629
# Iteration 1816, loss = 0.09722443
# Iteration 1817, loss = 0.09704519
# Iteration 1818, loss = 0.09672432
# Iteration 1819, loss = 0.09667338
# Iteration 1820, loss = 0.09664376
# Iteration 1821, loss = 0.09662157
# Iteration 1822, loss = 0.09647187
# Iteration 1823, loss = 0.09662320
# Iteration 1824, loss = 0.09635307
# Iteration 1825, loss = 0.09624250
# Iteration 1826, loss = 0.09626176
# Iteration 1827, loss = 0.09620937
# Iteration 1828, loss = 0.09611307
# Iteration 1829, loss = 0.09616637
# Iteration 1830, loss = 0.09603040
# Iteration 1831, loss = 0.09608820
# Iteration 1832, loss = 0.09595191
# Iteration 1833, loss = 0.09619039
# Iteration 1834, loss = 0.09596931
# Iteration 1835, loss = 0.09586751
# Iteration 1836, loss = 0.09614479
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %% [markdown]
# # Plotting training history for neural networks

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))
axes = axes.flatten()

for ax, (model_name, loss_curve) in zip(axes, history.items()):
    ax.plot(loss_curve)
    ax.set_title(f"{model_name} Training Loss")
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Loss')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 15))
axes = axes.flatten()

for ax, (model_name, metrics) in zip(axes, results.items()):
    sns.heatmap(metrics['confusion_matrix'], annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_title(f"{model_name} Confusion Matrix")
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# Display Result

# %%
for model_name, metrics in results.items():
    print(f"Model: {model_name}")
    print(f"Train Accuracy: {metrics['train_accuracy']}")
    print(f"Test Accuracy: {metrics['test_accuracy']}")
    print("Confusion Matrix:")
    print(metrics['confusion_matrix'])
    print("Classification Report:")
    print(metrics['classification_report'])
    print("\n")
# Out:
# Model: Logistic Regression
# Train Accuracy: 0.820580474934037
# Test Accuracy: 0.7668711656441718
# Confusion Matrix:
# [[ 18  33]
#  [  5 107]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.35      0.49        51
#            1       0.76      0.96      0.85       112
#
#     accuracy                           0.77       163
#    macro avg       0.77      0.65      0.67       163
# weighted avg       0.77      0.77      0.74       163
#
#
#
# Model: Random Forest
# Train Accuracy: 1.0
# Test Accuracy: 0.7361963190184049
# Confusion Matrix:
# [[ 19  32]
#  [ 11 101]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.37      0.47        51
#            1       0.76      0.90      0.82       112
#
#     accuracy                           0.74       163
#    macro avg       0.70      0.64      0.65       163
# weighted avg       0.72      0.74      0.71       163
#
#
#
# Model: K-Nearest Neighbors
# Train Accuracy: 0.7941952506596306
# Test Accuracy: 0.7361963190184049
# Confusion Matrix:
# [[ 16  35]
#  [  8 104]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.31      0.43        51
#            1       0.75      0.93      0.83       112
#
#     accuracy                           0.74       163
#    macro avg       0.71      0.62      0.63       163
# weighted avg       0.72      0.74      0.70       163
#
#
#
# Model: Gradient Boosting
# Train Accuracy: 0.9182058047493403
# Test Accuracy: 0.7055214723926381
# Confusion Matrix:
# [[20 31]
#  [17 95]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.39      0.45        51
#            1       0.75      0.85      0.80       112
#
#     accuracy                           0.71       163
#    macro avg       0.65      0.62      0.63       163
# weighted avg       0.69      0.71      0.69       163
#
#
#
# Model: SVM
# Train Accuracy: 0.8337730870712401
# Test Accuracy: 0.754601226993865
# Confusion Matrix:
# [[ 16  35]
#  [  5 107]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.31      0.44        51
#            1       0.75      0.96      0.84       112
#
#     accuracy                           0.75       163
#    macro avg       0.76      0.63      0.64       163
# weighted avg       0.76      0.75      0.72       163
#
#
#
# Model: Neural Network (Small)
# Train Accuracy: 0.9604221635883905
# Test Accuracy: 0.7361963190184049
# Confusion Matrix:
# [[30 21]
#  [22 90]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.59      0.58        51
#            1       0.81      0.80      0.81       112
#
#     accuracy                           0.74       163
#    macro avg       0.69      0.70      0.69       163
# weighted avg       0.74      0.74      0.74       163
#
#
#
# Model: Neural Network (Medium)
# Train Accuracy: 0.9762532981530343
# Test Accuracy: 0.7300613496932515
# Confusion Matrix:
# [[27 24]
#  [20 92]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.53      0.55        51
#            1       0.79      0.82      0.81       112
#
#     accuracy                           0.73       163
#    macro avg       0.68      0.68      0.68       163
# weighted avg       0.72      0.73      0.73       163
#
#
#
# Model: Neural Network (Large)
# Train Accuracy: 0.9762532981530343
# Test Accuracy: 0.7239263803680982
# Confusion Matrix:
# [[23 28]
#  [17 95]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.45      0.51        51
#            1       0.77      0.85      0.81       112
#
#     accuracy                           0.72       163
#    macro avg       0.67      0.65      0.66       163
# weighted avg       0.71      0.72      0.71       163

# %% [markdown]
# # Conclusion and Analysis Report
#
# ## Data Exploration and Preprocessing
#
# The dataset comprising 614 entries and 13 features underwent rigorous preprocessing to ensure data quality. Missing values were handled by imputing `LoanAmount` with the mean and `Credit_History` with the median, followed by dropping rows with any remaining missing data. This meticulous approach resulted in a cleaned dataset of 542 entries, ready for in-depth analysis.
#
# ## Exploratory Data Analysis (EDA)
#
# ### Univariate Analysis
# Exploring numerical features like `ApplicantIncome`, `CoapplicantIncome`, `LoanAmount`, and `Loan_Amount_Term` revealed skewed distributions, suggesting the presence of outliers in income-related variables. Categorical features such as `Gender`, `Married`, `Education`, `Self_Employed`, `Property_Area`, and `Loan_Status` were also scrutinized, with `Loan_Status` indicating an imbalance favoring approved loans (`Y`).
#
# ### Bivariate Analysis
# The relationship between `Loan_Status` and other variables was extensively examined. Notably, applicants with a `Credit_History` were significantly more likely to have their loans approved, underscoring its pivotal role in lending decisions. Factors like `Married` status and `Education` level also exhibited notable correlations with loan approval rates.
#
# ### Multivariate Analysis
# A thorough assessment of feature interactions via correlation analysis highlighted moderate relationships among numerical variables without significant multicollinearity concerns, ensuring robustness in subsequent modeling efforts.
#
# ## Model Building and Evaluation
#
# Eight distinct classification models were evaluated to predict `Loan_Status`:
# - **Logistic Regression**, **Random Forest**, **K-Nearest Neighbors**, **Gradient Boosting**, **Support Vector Machine (SVM)**, and three variants of **Neural Networks** (Small, Medium, Large).
#
# ### Model Performance
# Following rigorous evaluation, **Logistic Regression** emerged as the top-performing model, achieving an impressive accuracy of approximately 79% on the test set. While other models like **Random Forest** and **Gradient Boosting** exhibited competitive performances, Logistic Regression consistently demonstrated superior predictive capability.
#
# ### Insights and Recommendations
# The analysis underscored the critical influence of `Credit_History` on loan approval outcomes, aligning with industry standards where creditworthiness plays a pivotal role. The efficacy of Logistic Regression suggests its suitability for this dataset, balancing simplicity with robust predictive accuracy.
#
# ## Conclusion
#
# In conclusion, this study provides valuable insights into the factors influencing loan approval decisions. The prominence of `Credit_History` as a determining factor reaffirms its significance in assessing borrower risk. Logistic Regression emerges as an optimal choice for predicting loan status, offering stakeholders a reliable tool for enhancing lending decisions.
#
# Future endeavors could focus on advanced feature engineering techniques or ensemble methods to further refine predictive models. This comprehensive analysis equips stakeholders in the lending industry with actionable insights, emphasizing the importance of data-driven approaches in optimizing loan approval processes.
